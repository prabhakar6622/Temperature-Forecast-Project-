# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import warnings 

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:/Users/Jai Mata Di/Downloads/temperature.csv")

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df1=df.drop("station",axis=1)
at=df1.drop("Date",axis=1)

# %%
at.isnull().sum()
# Out:
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
at.dtypes
# Out:
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
at['Present_Tmax']=at['Present_Tmax'].replace('',np.nan)
at['Present_Tmax']=at['Present_Tmax'].fillna(np.mean(at["Present_Tmax"]))
at['Present_Tmin']=at['Present_Tmin'].replace('',np.nan)
at['Present_Tmin']=at['Present_Tmin'].fillna(np.mean(at["Present_Tmin"]))
at['LDAPS_RHmin']=at['LDAPS_RHmin'].replace('',np.nan)
at['LDAPS_RHmin']=at['LDAPS_RHmin'].fillna(np.mean(at["LDAPS_RHmin"]))
at['LDAPS_RHmax']=at['LDAPS_RHmax'].replace('',np.nan)
at['LDAPS_RHmax']=at['LDAPS_RHmax'].fillna(np.mean(at["LDAPS_RHmax"]))
at['LDAPS_Tmax_lapse']=at['LDAPS_Tmax_lapse'].replace('',np.nan)
at['LDAPS_Tmax_lapse']=at['LDAPS_Tmax_lapse'].fillna(np.mean(at["LDAPS_Tmax_lapse"]))
at['LDAPS_Tmin_lapse']=at['LDAPS_Tmin_lapse'].replace('',np.nan)
at['LDAPS_Tmin_lapse']=at['LDAPS_Tmin_lapse'].fillna(np.mean(at["LDAPS_Tmin_lapse"]))
at['LDAPS_WS']=at['LDAPS_WS'].replace('',np.nan)
at['LDAPS_WS']=at['LDAPS_WS'].fillna(np.mean(at["LDAPS_WS"]))
at['LDAPS_LH']=at['LDAPS_LH'].replace('',np.nan)
at['LDAPS_LH']=at['LDAPS_LH'].fillna(np.mean(at["LDAPS_LH"]))
at['LDAPS_CC1']=at['LDAPS_CC1'].replace('',np.nan)
at['LDAPS_CC1']=at['LDAPS_CC1'].fillna(np.mean(at["LDAPS_CC1"]))
at['LDAPS_CC2']=at['LDAPS_CC2'].replace('',np.nan)
at['LDAPS_CC2']=at['LDAPS_CC2'].fillna(np.mean(at["LDAPS_CC2"]))
at['LDAPS_CC3']=at['LDAPS_CC3'].replace('',np.nan)
at['LDAPS_CC3']=at['LDAPS_CC3'].fillna(np.mean(at["LDAPS_CC3"]))
at['LDAPS_CC4']=at['LDAPS_CC4'].replace('',np.nan)
at['LDAPS_CC4']=at['LDAPS_CC4'].fillna(np.mean(at["LDAPS_CC4"]))
at['LDAPS_PPT1']=at['LDAPS_PPT1'].replace('',np.nan)
at['LDAPS_PPT1']=at['LDAPS_PPT1'].fillna(np.mean(at["LDAPS_PPT1"]))
at.isnull().sum()at['LDAPS_PPT2']=at['LDAPS_PPT2'].replace('',np.nan)
at['LDAPS_PPT2']=at['LDAPS_PPT2'].fillna(np.mean(at["LDAPS_PPT2"]))
at['LDAPS_PPT3']=at['LDAPS_PPT3'].replace('',np.nan)
at['LDAPS_PPT3']=at['LDAPS_PPT3'].fillna(np.mean(at["LDAPS_PPT3"]))
at['LDAPS_PPT4']=at['LDAPS_PPT4'].replace('',np.nan)
at['LDAPS_PPT4']=at['LDAPS_PPT4'].fillna(np.mean(at["LDAPS_PPT4"]))
at['Next_Tmax']=at['Next_Tmax'].replace('',np.nan)
at['Next_Tmax']=at['Next_Tmax'].fillna(np.mean(at["Next_Tmax"]))
at['Next_Tmin']=at['Next_Tmin'].replace('',np.nan)
at['Next_Tmin']=at['Next_Tmin'].fillna(np.mean(at["Next_Tmin"]))

# %%
at.isnull().sum()
# Out:
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
tm=at.drop("Next_Tmin",axis=1)

# %%
tm
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0             28.7          21.4    58.255688    91.116364         28.074101
# 1             31.9          21.6    52.263397    90.604721         29.850689
# 2             31.6          23.3    48.690479    83.973587         30.091292
# 3             32.0          23.4    58.239788    96.483688         29.704629
# 4             31.4          21.9    56.174095    90.155128         29.113934
# ...            ...           ...          ...          ...               ...
# 7747          23.3          17.1    26.741310    78.869858         26.352081
# 7748          23.3          17.7    24.040634    77.294975         27.010193
# 7749          23.2          17.4    22.933014    77.243744         27.939516
# 7750          20.0          11.3    19.794666    58.936283         17.624954
# 7751          37.6          29.9    98.524734   100.000153         38.542255
#
#       LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            23.006936   6.818887   69.451805   0.233947   0.203896  ...
# 1            24.035009   5.691890   51.937448   0.225508   0.251771  ...
# 2            24.565633   6.138224   20.573050   0.209344   0.257469  ...
# 3            23.326177   5.650050   65.727144   0.216372   0.226002  ...
# 4            23.486480   5.735004  107.965535   0.151407   0.249995  ...
# ...                ...        ...         ...        ...        ...  ...
# 7747         18.775678   6.148918   72.058294   0.030034   0.081035  ...
# 7748         18.733519   6.542819   47.241457   0.035874   0.074962  ...
# 7749         18.522965   7.289264    9.090034   0.048954   0.059869  ...
# 7750         14.272646   2.882580  -13.603212   0.000000   0.000000  ...
# 7751         29.619342  21.857621  213.414006   0.967277   0.968353  ...
#
#       LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon  \
# 0       0.000000    0.000000    0.000000    0.000000  37.6046  126.991
# 1       0.000000    0.000000    0.000000    0.000000  37.6046  127.032
# 2       0.000000    0.000000    0.000000    0.000000  37.5776  127.058
# 3       0.000000    0.000000    0.000000    0.000000  37.6450  127.022
# 4       0.000000    0.000000    0.000000    0.000000  37.5507  127.135
# ...          ...         ...         ...         ...      ...      ...
# 7747    0.000000    0.000000    0.000000    0.000000  37.5372  126.891
# 7748    0.000000    0.000000    0.000000    0.000000  37.5237  126.909
# 7749    0.000000    0.000000    0.000000    0.000000  37.5237  126.970
# 7750    0.000000    0.000000    0.000000    0.000000  37.4562  126.826
# 7751   23.701544   21.621661   15.841235   16.655469  37.6450  127.135
#
#            DEM     Slope  Solar radiation  Next_Tmax
# 0     212.3350  2.785000      5992.895996       29.1
# 1      44.7624  0.514100      5869.312500       30.5
# 2      33.3068  0.266100      5863.555664       31.1
# 3      45.7160  2.534800      5856.964844       31.7
# 4      35.0380  0.505500      5859.552246       31.2
# ...        ...       ...              ...        ...
# 7747   15.5876  0.155400      4443.313965       28.3
# 7748   17.2956  0.222300      4438.373535       28.6
# 7749   19.5844  0.271300      4451.345215       27.8
# 7750   12.3700  0.098475      4329.520508       17.4
# 7751  212.3350  5.178230      5992.895996       38.9
#
# [7752 rows x 22 columns]

# %%
tm.corr()
# Out:
#                   Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Present_Tmax          1.000000      0.618760    -0.204571    -0.301787
# Present_Tmin          0.618760      1.000000     0.123143    -0.015140
# LDAPS_RHmin          -0.204571      0.123143     1.000000     0.579141
# LDAPS_RHmax          -0.301787     -0.015140     0.579141     1.000000
# LDAPS_Tmax_lapse      0.570129      0.464151    -0.564580    -0.373404
# LDAPS_Tmin_lapse      0.623496      0.762993     0.089476    -0.114143
# LDAPS_WS             -0.121820     -0.034675     0.294361     0.135333
# LDAPS_LH              0.135463     -0.009258    -0.070858     0.238579
# LDAPS_CC1            -0.311805      0.084447     0.613818     0.436652
# LDAPS_CC2            -0.213791      0.090263     0.745443     0.391330
# LDAPS_CC3            -0.144018     -0.002772     0.689679     0.226957
# LDAPS_CC4            -0.140729     -0.044335     0.514075     0.130619
# LDAPS_PPT1           -0.109006      0.112845     0.262665     0.268449
# LDAPS_PPT2           -0.099449      0.068176     0.390967     0.229050
# LDAPS_PPT3           -0.120367     -0.046126     0.240642     0.134607
# LDAPS_PPT4           -0.099607     -0.062965     0.168595     0.117853
# lat                  -0.052615     -0.078475     0.087099     0.195798
# lon                   0.009020     -0.043461    -0.076237     0.025667
# DEM                  -0.187121     -0.250275     0.102115     0.177168
# Slope                -0.105809     -0.146339     0.123744     0.219599
# Solar radiation      -0.025439      0.053578     0.244080     0.149261
# Next_Tmax             0.610348      0.471806    -0.437898    -0.283738
#
#                   LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  \
# Present_Tmax              0.570129          0.623496 -0.121820  0.135463
# Present_Tmin              0.464151          0.762993 -0.034675 -0.009258
# LDAPS_RHmin              -0.564580          0.089476  0.294361 -0.070858
# LDAPS_RHmax              -0.373404         -0.114143  0.135333  0.238579
# LDAPS_Tmax_lapse          1.000000          0.654021 -0.311996  0.048010
# LDAPS_Tmin_lapse          0.654021          1.000000 -0.130035 -0.134761
# LDAPS_WS                 -0.311996         -0.130035  1.000000  0.006711
# LDAPS_LH                  0.048010         -0.134761  0.006711  1.000000
# LDAPS_CC1                -0.438439          0.010901  0.289445 -0.147296
# LDAPS_CC2                -0.523619          0.047727  0.261090 -0.264280
# LDAPS_CC3                -0.541327         -0.044018  0.242991 -0.245583
# LDAPS_CC4                -0.429539         -0.080335  0.220533 -0.172766
# LDAPS_PPT1               -0.111065          0.038056  0.152587 -0.012542
# LDAPS_PPT2               -0.242122          0.000870  0.191886 -0.077545
# LDAPS_PPT3               -0.188115         -0.088575  0.161684  0.016102
# LDAPS_PPT4               -0.160273         -0.094655  0.144085  0.019979
# lat                      -0.042093         -0.096257  0.036657  0.133221
# lon                       0.090666         -0.026701 -0.059466  0.025822
# DEM                      -0.178895         -0.195455  0.191053  0.055133
# Slope                    -0.162332         -0.185849  0.171629  0.086781
# Solar radiation           0.047971          0.159975  0.121759 -0.047384
# Next_Tmax                 0.827189          0.586983 -0.342729  0.157616
#
#                   LDAPS_CC1  LDAPS_CC2  ...  LDAPS_PPT1  LDAPS_PPT2  \
# Present_Tmax      -0.311805  -0.213791  ...   -0.109006   -0.099449
# Present_Tmin       0.084447   0.090263  ...    0.112845    0.068176
# LDAPS_RHmin        0.613818   0.745443  ...    0.262665    0.390967
# LDAPS_RHmax        0.436652   0.391330  ...    0.268449    0.229050
# LDAPS_Tmax_lapse  -0.438439  -0.523619  ...   -0.111065   -0.242122
# LDAPS_Tmin_lapse   0.010901   0.047727  ...    0.038056    0.000870
# LDAPS_WS           0.289445   0.261090  ...    0.152587    0.191886
# LDAPS_LH          -0.147296  -0.264280  ...   -0.012542   -0.077545
# LDAPS_CC1          1.000000   0.779683  ...    0.446328    0.389453
# LDAPS_CC2          0.779683   1.000000  ...    0.305975    0.478472
# LDAPS_CC3          0.517493   0.725813  ...    0.159280    0.337569
# LDAPS_CC4          0.361046   0.527708  ...    0.120483    0.288195
# LDAPS_PPT1         0.446328   0.305975  ...    1.000000    0.383831
# LDAPS_PPT2         0.389453   0.478472  ...    0.383831    1.000000
# LDAPS_PPT3         0.168742   0.240134  ...    0.033004    0.221172
# LDAPS_PPT4         0.091722   0.159548  ...    0.024626    0.139555
# lat               -0.008131  -0.001497  ...    0.000565    0.019564
# lon               -0.006843  -0.003581  ...   -0.001225    0.018600
# DEM               -0.014090  -0.012823  ...    0.011290    0.008357
# Slope             -0.020752  -0.018073  ...    0.016310    0.010214
# Solar radiation    0.218309   0.170403  ...    0.088015    0.110182
# Next_Tmax         -0.452541  -0.490756  ...   -0.118817   -0.178383
#
#                   LDAPS_PPT3  LDAPS_PPT4       lat       lon       DEM  \
# Present_Tmax       -0.120367   -0.099607 -0.052615  0.009020 -0.187121
# Present_Tmin       -0.046126   -0.062965 -0.078475 -0.043461 -0.250275
# LDAPS_RHmin         0.240642    0.168595  0.087099 -0.076237  0.102115
# LDAPS_RHmax         0.134607    0.117853  0.195798  0.025667  0.177168
# LDAPS_Tmax_lapse   -0.188115   -0.160273 -0.042093  0.090666 -0.178895
# LDAPS_Tmin_lapse   -0.088575   -0.094655 -0.096257 -0.026701 -0.195455
# LDAPS_WS            0.161684    0.144085  0.036657 -0.059466  0.191053
# LDAPS_LH            0.016102    0.019979  0.133221  0.025822  0.055133
# LDAPS_CC1           0.168742    0.091722 -0.008131 -0.006843 -0.014090
# LDAPS_CC2           0.240134    0.159548 -0.001497 -0.003581 -0.012823
# LDAPS_CC3           0.339800    0.302357  0.004108  0.016041  0.000697
# LDAPS_CC4           0.267494    0.376049 -0.009107 -0.002477 -0.007334
# LDAPS_PPT1          0.033004    0.024626  0.000565 -0.001225  0.011290
# LDAPS_PPT2          0.221172    0.139555  0.019564  0.018600  0.008357
# LDAPS_PPT3          1.000000    0.309076  0.035110  0.021662  0.017186
# LDAPS_PPT4          0.309076    1.000000  0.013210  0.044746 -0.003622
# lat                 0.035110    0.013210  1.000000  0.289029  0.033165
# lon                 0.021662    0.044746  0.289029  1.000000  0.007587
# DEM                 0.017186   -0.003622  0.033165  0.007587  1.000000
# Slope               0.025333    0.000117  0.074763  0.038070  0.783576
# Solar radiation    -0.054071    0.034958  0.038513  0.002182  0.056224
# Next_Tmax          -0.194143   -0.178718 -0.053510  0.003052 -0.172538
#
#                      Slope  Solar radiation  Next_Tmax
# Present_Tmax     -0.105809        -0.025439   0.610348
# Present_Tmin     -0.146339         0.053578   0.471806
# LDAPS_RHmin       0.123744         0.244080  -0.437898
# LDAPS_RHmax       0.219599         0.149261  -0.283738
# LDAPS_Tmax_lapse -0.162332         0.047971   0.827189
# LDAPS_Tmin_lapse -0.185849         0.159975   0.586983
# LDAPS_WS          0.171629         0.121759  -0.342729
# LDAPS_LH          0.086781        -0.047384   0.157616
# LDAPS_CC1        -0.020752         0.218309  -0.452541
# LDAPS_CC2        -0.018073         0.170403  -0.490756
# LDAPS_CC3        -0.003338         0.119292  -0.514680
# LDAPS_CC4        -0.014459         0.119983  -0.446319
# LDAPS_PPT1        0.016310         0.088015  -0.118817
# LDAPS_PPT2        0.010214         0.110182  -0.178383
# LDAPS_PPT3        0.025333        -0.054071  -0.194143
# LDAPS_PPT4        0.000117         0.034958  -0.178718
# lat               0.074763         0.038513  -0.053510
# lon               0.038070         0.002182   0.003052
# DEM               0.783576         0.056224  -0.172538
# Slope             1.000000         0.028199  -0.102725
# Solar radiation   0.028199         1.000000   0.008795
# Next_Tmax        -0.102725         0.008795   1.000000
#
# [22 rows x 22 columns]

# %%
tm.corr()['Next_Tmax'].sort_values(ascending=False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.827189
# Present_Tmax        0.610348
# LDAPS_Tmin_lapse    0.586983
# Present_Tmin        0.471806
# LDAPS_LH            0.157616
# Solar radiation     0.008795
# lon                 0.003052
# lat                -0.053510
# Slope              -0.102725
# LDAPS_PPT1         -0.118817
# DEM                -0.172538
# LDAPS_PPT2         -0.178383
# LDAPS_PPT4         -0.178718
# LDAPS_PPT3         -0.194143
# LDAPS_RHmax        -0.283738
# LDAPS_WS           -0.342729
# LDAPS_RHmin        -0.437898
# LDAPS_CC4          -0.446319
# LDAPS_CC1          -0.452541
# LDAPS_CC2          -0.490756
# LDAPS_CC3          -0.514680
# Name: Next_Tmax, dtype: float64

# %%
import matplotlib.pyplot as plt  
plt.figure(figsize=(15,7))
sns.heatmap(tm.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
tm.describe()
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7752.000000   7752.000000  7752.000000  7752.000000       7752.000000
# mean      29.768211     23.225059    56.759372    88.374804         29.613447
# std        2.956557      2.403036    14.596973     7.157124          2.932898
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.700000    46.046162    84.316923         27.693091
# 50%       29.900000     23.400000    55.313244    89.699505         29.662273
# 75%       32.000000     24.900000    67.038254    93.704500         31.683819
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean          23.512589     7.097875    62.505019     0.368774     0.356080
# std            2.333973     2.173245    33.567001     0.261185     0.256810
# min           14.272646     2.882580   -13.603212     0.000000     0.000000
# 25%           22.114651     5.686487    37.532764     0.148321     0.142328
# 50%           23.735942     6.563068    57.310630     0.320110     0.315667
# 75%           25.134000     8.007471    83.904586     0.571696     0.554963
# max           29.619342    21.857621   213.414006     0.967277     0.968353
#
#        ...   LDAPS_PPT1   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  ...  7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean   ...     0.591995     0.485003     0.278200     0.269407    37.544722
# std    ...     1.936331     1.754258     1.156174     1.200364     0.050352
# min    ...     0.000000     0.000000     0.000000     0.000000    37.456200
# 25%    ...     0.000000     0.000000     0.000000     0.000000    37.510200
# 50%    ...     0.000000     0.000000     0.000000     0.000000    37.550700
# 75%    ...     0.067593     0.024276     0.009697     0.000693    37.577600
# max    ...    23.701544    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax
# count  7752.000000  7752.000000  7752.000000      7752.000000  7752.000000
# mean    126.991397    61.867972     1.257048      5341.502803    30.274887
# std       0.079435    54.279780     1.370444       429.158867     3.122557
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.200000
# 50%     126.995000    45.716000     0.618000      5436.345215    30.500000
# 75%     127.042000    59.832400     1.767800      5728.316406    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
# [8 rows x 22 columns]

# %%
tm.plot(kind='density',subplots=True,layout=(6,6),sharex=False,legend=False, fontsize=1,figsize=(18,12))
plt.show()

# %%
x=tm.drop("Next_Tmax",axis=1)
y=tm["Next_Tmax"]

# %%
x.skew().sort_values(ascending=False)
# Out:
# LDAPS_PPT4          6.825464
# LDAPS_PPT3          6.457129
# LDAPS_PPT2          5.775355
# LDAPS_PPT1          5.393821
# DEM                 1.723257
# LDAPS_WS            1.579236
# Slope               1.563020
# LDAPS_LH            0.673757
# LDAPS_CC4           0.666482
# LDAPS_CC3           0.640735
# LDAPS_CC2           0.472350
# LDAPS_CC1           0.459458
# LDAPS_RHmin         0.300220
# lat                 0.087062
# LDAPS_Tmax_lapse   -0.227880
# Present_Tmax       -0.264137
# lon                -0.285213
# Present_Tmin       -0.367538
# Solar radiation    -0.511210
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_RHmax        -0.855015
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.408897     -0.797707     0.172680     0.272915         -0.556645
# 1         0.705123     -0.720130    -0.241770     0.185831          0.043756
# 2         0.595692     -0.027674    -0.501459    -0.773454          0.127214
# 3         0.741829      0.014910     0.171612     1.316777         -0.006660
# 4         0.523313     -0.602237     0.031496     0.110968         -0.208627
# ...            ...           ...          ...          ...               ...
# 7747     -2.023162     -2.270927    -2.395892    -1.326845         -1.111724
# 7748     -2.023162     -2.087438    -2.681557    -1.470235         -0.902733
# 7749     -2.049920     -2.180066    -2.803707    -1.474702         -0.600985
# 7750     -2.846187     -3.688005    -3.168120    -2.459357         -3.504186
# 7751      2.981037      3.233078     2.489550     2.143982          3.376037
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            -0.312411  0.093387  0.310382  -0.412176  -0.506509  ...
# 1             0.144368 -0.625565 -0.211695  -0.451258  -0.283702  ...
# 2             0.394571 -0.314874 -1.375126  -0.527382  -0.258127  ...
# 3            -0.174463 -0.656732  0.204179  -0.494077  -0.401828  ...
# 4            -0.103881 -0.593836  1.300503  -0.814752  -0.291713  ...
# ...                ...       ...       ...        ...        ...  ...
# 7747         -1.831134 -0.307886  0.383363  -1.502656  -1.152361  ...
# 7748         -1.843546 -0.063701 -0.363041  -1.466503  -1.187449  ...
# 7749         -1.904782  0.337939 -1.973052  -1.386744  -1.276108  ...
# 7750         -2.891504 -4.119648 -7.414001  -1.694130  -1.649551  ...
# 7751          3.309654  3.033873  3.452681   1.866462   1.920855  ...
#
#       LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4  lat  \
# 0     -0.584801   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 1     -0.603593   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 2     -0.520112   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 3     -0.565449   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 4     -0.365736   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# ...         ...         ...         ...         ...         ...  ...
# 7747  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7748  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7749  -1.474280   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7750  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7751   1.894287    2.163899    2.336183    2.512023    2.631958  0.0
#
#            lon       DEM     Slope  Solar radiation
# 0    -0.027632  1.834978  1.314153         1.849430
# 1     0.497283  0.055979 -0.385336         1.400702
# 2     0.836548 -0.364575 -0.949164         1.380650
# 3     0.368125  0.084879  1.235263         1.357783
# 4     1.871193 -0.290442 -0.401730         1.366748
# ...        ...       ...       ...              ...
# 7747 -1.257759 -1.578128 -1.280447        -1.754608
# 7748 -1.041466 -1.400633 -1.072947        -1.760631
# 7749 -0.291792 -1.193124 -0.935044        -1.744763
# 7750 -2.020630 -1.985144 -1.477264        -1.887071
# 7751  1.871193  1.834978  1.742163         1.849430
#
# [7752 rows x 21 columns]

# %%
x.skew().sort_values(ascending=False)
# Out:
# LDAPS_PPT4          1.963848
# LDAPS_PPT3          1.747820
# LDAPS_PPT2          1.577808
# LDAPS_PPT1          1.404189
# Slope               0.233968
# LDAPS_CC4           0.126895
# LDAPS_CC3           0.087933
# LDAPS_LH            0.057403
# LDAPS_CC1           0.046757
# LDAPS_CC2           0.045326
# DEM                 0.039456
# LDAPS_WS            0.002408
# lat                 0.000000
# LDAPS_Tmax_lapse   -0.009351
# Present_Tmin       -0.012048
# LDAPS_RHmin        -0.017469
# LDAPS_Tmin_lapse   -0.017827
# Present_Tmax       -0.035006
# LDAPS_RHmax        -0.115143
# Solar radiation    -0.176636
# lon                -0.198429
# dtype: float64

# %%
sk=x.skew()

# %%
sk[np.abs(sk)>0.25].all()
# Out:
# True

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
x
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.408897     -0.797707     0.172680     0.272915         -0.556645
# 1         0.705123     -0.720130    -0.241770     0.185831          0.043756
# 2         0.595692     -0.027674    -0.501459    -0.773454          0.127214
# 3         0.741829      0.014910     0.171612     1.316777         -0.006660
# 4         0.523313     -0.602237     0.031496     0.110968         -0.208627
# ...            ...           ...          ...          ...               ...
# 7747     -2.023162     -2.270927    -2.395892    -1.326845         -1.111724
# 7748     -2.023162     -2.087438    -2.681557    -1.470235         -0.902733
# 7749     -2.049920     -2.180066    -2.803707    -1.474702         -0.600985
# 7750     -2.846187     -3.688005    -3.168120    -2.459357         -3.504186
# 7751      2.981037      3.233078     2.489550     2.143982          3.376037
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            -0.312411  0.093387  0.310382  -0.412176  -0.506509  ...
# 1             0.144368 -0.625565 -0.211695  -0.451258  -0.283702  ...
# 2             0.394571 -0.314874 -1.375126  -0.527382  -0.258127  ...
# 3            -0.174463 -0.656732  0.204179  -0.494077  -0.401828  ...
# 4            -0.103881 -0.593836  1.300503  -0.814752  -0.291713  ...
# ...                ...       ...       ...        ...        ...  ...
# 7747         -1.831134 -0.307886  0.383363  -1.502656  -1.152361  ...
# 7748         -1.843546 -0.063701 -0.363041  -1.466503  -1.187449  ...
# 7749         -1.904782  0.337939 -1.973052  -1.386744  -1.276108  ...
# 7750         -2.891504 -4.119648 -7.414001  -1.694130  -1.649551  ...
# 7751          3.309654  3.033873  3.452681   1.866462   1.920855  ...
#
#       LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4  lat  \
# 0     -0.584801   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 1     -0.603593   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 2     -0.520112   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 3     -0.565449   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 4     -0.365736   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# ...         ...         ...         ...         ...         ...  ...
# 7747  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7748  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7749  -1.474280   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7750  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7751   1.894287    2.163899    2.336183    2.512023    2.631958  0.0
#
#            lon       DEM     Slope  Solar radiation
# 0    -0.027632  1.834978  1.314153         1.849430
# 1     0.497283  0.055979 -0.385336         1.400702
# 2     0.836548 -0.364575 -0.949164         1.380650
# 3     0.368125  0.084879  1.235263         1.357783
# 4     1.871193 -0.290442 -0.401730         1.366748
# ...        ...       ...       ...              ...
# 7747 -1.257759 -1.578128 -1.280447        -1.754608
# 7748 -1.041466 -1.400633 -1.072947        -1.760631
# 7749 -0.291792 -1.193124 -0.935044        -1.744763
# 7750 -2.020630 -1.985144 -1.477264        -1.887071
# 7751  1.871193  1.834978  1.742163         1.849430
#
# [7752 rows x 21 columns]

# %%
y
# Out:
# 0       29.1
# 1       30.5
# 2       31.1
# 3       31.7
# 4       31.2
#         ...
# 7747    28.3
# 7748    28.6
# 7749    27.8
# 7750    17.4
# 7751    38.9
# Name: Next_Tmax, Length: 7752, dtype: float64

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score

# %%
for i in range (0,2000) :
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    print(f"at random state {i},the training accuracy is :{r2_score(y_train,pred_train)}")
    print(f"at random state {i},the testing accuracy is :{r2_score(y_test,pred_test)}") 
    print("\n")
# Out:
# at random state 0,the training accuracy is :0.7525743636402242
# at random state 0,the testing accuracy is :0.76344157578477
#
#
# at random state 1,the training accuracy is :0.752404101060585
# at random state 1,the testing accuracy is :0.7645020263434288
#
#
# at random state 2,the training accuracy is :0.755891925819514
# at random state 2,the testing accuracy is :0.7506191584487096
#
#
# at random state 3,the training accuracy is :0.7559262439868314
# at random state 3,the testing accuracy is :0.7505682674948795
#
#
# at random state 4,the training accuracy is :0.7515032498204299
# at random state 4,the testing accuracy is :0.767749023408882
#
#
# at random state 5,the training accuracy is :0.7533382391168663
# at random state 5,the testing accuracy is :0.7600864436296597
#
#
# at random state 6,the training accuracy is :0.7546313845308519
# at random state 6,the testing accuracy is :0.754999763765838
#
#
# at random state 7,the training accuracy is :0.7551697168103512
# at random state 7,the testing accuracy is :0.7527667037444576
#
#
# at random state 8,the training accuracy is :0.7618268024573909
# at random state 8,the testing accuracy is :0.7258785012557941
#
#
# at random state 9,the training accuracy is :0.7537380591917875
# at random state 9,the testing accuracy is :0.7592650730031184
#
#
# at random state 10,the training accuracy is :0.7554681404669246
# at random state 10,the testing accuracy is :0.7521479533086973
#
#
# at random state 11,the training accuracy is :0.7559811108986128
# at random state 11,the testing accuracy is :0.750201758021527
#
#
# at random state 12,the training accuracy is :0.7510550858671714
# at random state 12,the testing accuracy is :0.7684795234216012
#
#
# at random state 13,the training accuracy is :0.7549141906235868
# at random state 13,the testing accuracy is :0.75456601940836
#
#
# at random state 14,the training accuracy is :0.7543897097037734
# at random state 14,the testing accuracy is :0.7567699231607635
#
#
# at random state 15,the training accuracy is :0.7599413436616899
# at random state 15,the testing accuracy is :0.7335422710559849
#
#
# at random state 16,the training accuracy is :0.7536657422975892
# at random state 16,the testing accuracy is :0.7594143794031194
#
#
# at random state 17,the training accuracy is :0.7555248002784486
# at random state 17,the testing accuracy is :0.7518654964216427
#
#
# at random state 18,the training accuracy is :0.76114705656138
# at random state 18,the testing accuracy is :0.7273215758201756
#
#
# at random state 19,the training accuracy is :0.7581219259032937
# at random state 19,the testing accuracy is :0.7402130295847917
#
#
# at random state 20,the training accuracy is :0.7532650703085133
# at random state 20,the testing accuracy is :0.760668919551095
#
#
# at random state 21,the training accuracy is :0.7555608812148357
# at random state 21,the testing accuracy is :0.7517796846269834
#
#
# at random state 22,the training accuracy is :0.7594066145858482
# at random state 22,the testing accuracy is :0.7361210987047264
#
#
# at random state 23,the training accuracy is :0.755613302560452
# at random state 23,the testing accuracy is :0.7519787827635234
#
#
# at random state 24,the training accuracy is :0.7502224418617164
# at random state 24,the testing accuracy is :0.7724978482018136
#
#
# at random state 25,the training accuracy is :0.7551897032570043
# at random state 25,the testing accuracy is :0.7533645454226598
#
#
# at random state 26,the training accuracy is :0.75531793204547
# at random state 26,the testing accuracy is :0.752967994454921
#
#
# at random state 27,the training accuracy is :0.7549254951232652
# at random state 27,the testing accuracy is :0.7542196358272519
#
#
# at random state 28,the training accuracy is :0.7505132303523467
# at random state 28,the testing accuracy is :0.7704053658666447
#
#
# at random state 29,the training accuracy is :0.7581892362184847
# at random state 29,the testing accuracy is :0.7408246219670898
#
#
# at random state 30,the training accuracy is :0.7539475009152569
# at random state 30,the testing accuracy is :0.758183997926136
#
#
# at random state 31,the training accuracy is :0.7571125714185101
# at random state 31,the testing accuracy is :0.7449462766745059
#
#
# at random state 32,the training accuracy is :0.7568991800683478
# at random state 32,the testing accuracy is :0.7456746396964452
#
#
# at random state 33,the training accuracy is :0.757829031387363
# at random state 33,the testing accuracy is :0.742003051756178
#
#
# at random state 34,the training accuracy is :0.7530391684035155
# at random state 34,the testing accuracy is :0.7613034917297502
#
#
# at random state 35,the training accuracy is :0.758737189163365
# at random state 35,the testing accuracy is :0.7382808637293548
#
#
# at random state 36,the training accuracy is :0.7542723826307548
# at random state 36,the testing accuracy is :0.7571066559896406
#
#
# at random state 37,the training accuracy is :0.7555770955854922
# at random state 37,the testing accuracy is :0.7518530801235933
#
#
# at random state 38,the training accuracy is :0.7515056160793224
# at random state 38,the testing accuracy is :0.7679422102046713
#
#
# at random state 39,the training accuracy is :0.7547513056799853
# at random state 39,the testing accuracy is :0.7552433738758801
#
#
# at random state 40,the training accuracy is :0.7540812766823823
# at random state 40,the testing accuracy is :0.7575230075766537
#
#
# at random state 41,the training accuracy is :0.7567014801707378
# at random state 41,the testing accuracy is :0.7473702867562921
#
#
# at random state 42,the training accuracy is :0.7547458176853374
# at random state 42,the testing accuracy is :0.75469540402724
#
#
# at random state 43,the training accuracy is :0.7507499535402604
# at random state 43,the testing accuracy is :0.7711748971459039
#
#
# at random state 44,the training accuracy is :0.7564851898536122
# at random state 44,the testing accuracy is :0.7474581513694074
#
#
# at random state 45,the training accuracy is :0.7546362273946952
# at random state 45,the testing accuracy is :0.7546451112272636
#
#
# at random state 46,the training accuracy is :0.754010171055513
# at random state 46,the testing accuracy is :0.7579293864905867
#
#
# at random state 47,the training accuracy is :0.7588833372181881
# at random state 47,the testing accuracy is :0.7368755889574086
#
#
# at random state 48,the training accuracy is :0.7545560282481506
# at random state 48,the testing accuracy is :0.7558343415219427
#
#
# at random state 49,the training accuracy is :0.7549448847547149
# at random state 49,the testing accuracy is :0.7544579108335454
#
#
# at random state 50,the training accuracy is :0.7639979305346634
# at random state 50,the testing accuracy is :0.7171249204323333
#
#
# at random state 51,the training accuracy is :0.7529380812476282
# at random state 51,the testing accuracy is :0.7620686148519561
#
#
# at random state 52,the training accuracy is :0.7545805844573883
# at random state 52,the testing accuracy is :0.7557610643703001
#
#
# at random state 53,the training accuracy is :0.7547346544888812
# at random state 53,the testing accuracy is :0.7548123768023245
#
#
# at random state 54,the training accuracy is :0.7564675144990748
# at random state 54,the testing accuracy is :0.7480703505981523
#
#
# at random state 55,the training accuracy is :0.7554183864344061
# at random state 55,the testing accuracy is :0.7525422391074412
#
#
# at random state 56,the training accuracy is :0.7501823002068947
# at random state 56,the testing accuracy is :0.7709157891193921
#
#
# at random state 57,the training accuracy is :0.7590808232261599
# at random state 57,the testing accuracy is :0.7376916811788008
#
#
# at random state 58,the training accuracy is :0.7549150943688739
# at random state 58,the testing accuracy is :0.7538693001710907
#
#
# at random state 59,the training accuracy is :0.7495958147710607
# at random state 59,the testing accuracy is :0.7744332364920139
#
#
# at random state 60,the training accuracy is :0.7533689685870657
# at random state 60,the testing accuracy is :0.7601476519382305
#
#
# at random state 61,the training accuracy is :0.7511453083710546
# at random state 61,the testing accuracy is :0.7695812325523221
#
#
# at random state 62,the training accuracy is :0.752631016426711
# at random state 62,the testing accuracy is :0.7634063509168694
#
#
# at random state 63,the training accuracy is :0.7530504214636361
# at random state 63,the testing accuracy is :0.7609170810702525
#
#
# at random state 64,the training accuracy is :0.7573309611322584
# at random state 64,the testing accuracy is :0.7443932513263222
#
#
# at random state 65,the training accuracy is :0.758049851267014
# at random state 65,the testing accuracy is :0.7419630482941276
#
#
# at random state 66,the training accuracy is :0.7583116180154327
# at random state 66,the testing accuracy is :0.7408645926328487
#
#
# at random state 67,the training accuracy is :0.7534696576905391
# at random state 67,the testing accuracy is :0.7605282175629289
#
#
# at random state 68,the training accuracy is :0.7531519850942145
# at random state 68,the testing accuracy is :0.7612425945899496
#
#
# at random state 69,the training accuracy is :0.7539990926212707
# at random state 69,the testing accuracy is :0.7583750790286923
#
#
# at random state 70,the training accuracy is :0.7569868610234981
# at random state 70,the testing accuracy is :0.7460452290283699
#
#
# at random state 71,the training accuracy is :0.7530874221190715
# at random state 71,the testing accuracy is :0.7608105088384277
#
#
# at random state 72,the training accuracy is :0.7546117798366474
# at random state 72,the testing accuracy is :0.7554753090635976
#
#
# at random state 73,the training accuracy is :0.7547756579637976
# at random state 73,the testing accuracy is :0.7548733123125541
#
#
# at random state 74,the training accuracy is :0.7542965603764802
# at random state 74,the testing accuracy is :0.7567753054730519
#
#
# at random state 75,the training accuracy is :0.7591033354425508
# at random state 75,the testing accuracy is :0.7377758950896995
#
#
# at random state 76,the training accuracy is :0.7556543066502092
# at random state 76,the testing accuracy is :0.7518792315864327
#
#
# at random state 77,the training accuracy is :0.7558082574192231
# at random state 77,the testing accuracy is :0.7509636872946703
#
#
# at random state 78,the training accuracy is :0.7538316941608816
# at random state 78,the testing accuracy is :0.7589450869246994
#
#
# at random state 79,the training accuracy is :0.7510148735620934
# at random state 79,the testing accuracy is :0.770708693825146
#
#
# at random state 80,the training accuracy is :0.7560066815890791
# at random state 80,the testing accuracy is :0.7500891323586307
#
#
# at random state 81,the training accuracy is :0.7569116911903988
# at random state 81,the testing accuracy is :0.74576613849682
#
#
# at random state 82,the training accuracy is :0.7558858730113679
# at random state 82,the testing accuracy is :0.7507285832258553
#
#
# at random state 83,the training accuracy is :0.7599682772816652
# at random state 83,the testing accuracy is :0.734474160126171
#
#
# at random state 84,the training accuracy is :0.7545188816732495
# at random state 84,the testing accuracy is :0.755696320344599
#
#
# at random state 85,the training accuracy is :0.759348896430567
# at random state 85,the testing accuracy is :0.7369090482716294
#
#
# at random state 86,the training accuracy is :0.7529524165963941
# at random state 86,the testing accuracy is :0.7622207479350797
#
#
# at random state 87,the training accuracy is :0.7582227833533112
# at random state 87,the testing accuracy is :0.7411952751440417
#
#
# at random state 88,the training accuracy is :0.7511119308333883
# at random state 88,the testing accuracy is :0.7687458370375121
#
#
# at random state 89,the training accuracy is :0.7521610165465589
# at random state 89,the testing accuracy is :0.7653968889670761
#
#
# at random state 90,the training accuracy is :0.7507427541138844
# at random state 90,the testing accuracy is :0.770030658125969
#
#
# at random state 91,the training accuracy is :0.7581663931633529
# at random state 91,the testing accuracy is :0.7396801779650806
#
#
# at random state 92,the training accuracy is :0.7564357777103202
# at random state 92,the testing accuracy is :0.7481461103876714
#
#
# at random state 93,the training accuracy is :0.7551228243303959
# at random state 93,the testing accuracy is :0.7536296628460718
#
#
# at random state 94,the training accuracy is :0.7510409400189528
# at random state 94,the testing accuracy is :0.7687025133343378
#
#
# at random state 95,the training accuracy is :0.7565204845261047
# at random state 95,the testing accuracy is :0.7477798841646828
#
#
# at random state 96,the training accuracy is :0.7564385109082322
# at random state 96,the testing accuracy is :0.7480153093707188
#
#
# at random state 97,the training accuracy is :0.7562670299587463
# at random state 97,the testing accuracy is :0.7484848496160045
#
#
# at random state 98,the training accuracy is :0.7581901585937143
# at random state 98,the testing accuracy is :0.7415459643401476
#
#
# at random state 99,the training accuracy is :0.7551171823767846
# at random state 99,the testing accuracy is :0.7528606167859772
#
#
# at random state 100,the training accuracy is :0.7571194254239302
# at random state 100,the testing accuracy is :0.745271618139978
#
#
# at random state 101,the training accuracy is :0.7521930804296474
# at random state 101,the testing accuracy is :0.7645418583182868
#
#
# at random state 102,the training accuracy is :0.7508321981421165
# at random state 102,the testing accuracy is :0.7702205965172852
#
#
# at random state 103,the training accuracy is :0.757601202305454
# at random state 103,the testing accuracy is :0.7430478837030017
#
#
# at random state 104,the training accuracy is :0.7533255836777828
# at random state 104,the testing accuracy is :0.7602268622467259
#
#
# at random state 105,the training accuracy is :0.7504195733057033
# at random state 105,the testing accuracy is :0.7715860078552365
#
#
# at random state 106,the training accuracy is :0.7531258946407153
# at random state 106,the testing accuracy is :0.7616724634447132
#
#
# at random state 107,the training accuracy is :0.7600179628957022
# at random state 107,the testing accuracy is :0.7319142518565465
#
#
# at random state 108,the training accuracy is :0.7519241143910163
# at random state 108,the testing accuracy is :0.765864386779213
#
#
# at random state 109,the training accuracy is :0.7542395187180787
# at random state 109,the testing accuracy is :0.7570470807698204
#
#
# at random state 110,the training accuracy is :0.7571888446653751
# at random state 110,the testing accuracy is :0.7451049041642391
#
#
# at random state 111,the training accuracy is :0.7539376634871667
# at random state 111,the testing accuracy is :0.7579996397582733
#
#
# at random state 112,the training accuracy is :0.7565481506276815
# at random state 112,the testing accuracy is :0.7481334820243073
#
#
# at random state 113,the training accuracy is :0.7561656824595102
# at random state 113,the testing accuracy is :0.7485440354810683
#
#
# at random state 114,the training accuracy is :0.7536262760734685
# at random state 114,the testing accuracy is :0.759911757620992
#
#
# at random state 115,the training accuracy is :0.7544695371019098
# at random state 115,the testing accuracy is :0.7559008005349754
#
#
# at random state 116,the training accuracy is :0.750858575932907
# at random state 116,the testing accuracy is :0.7693844238097047
#
#
# at random state 117,the training accuracy is :0.7560933197357544
# at random state 117,the testing accuracy is :0.7496267840124888
#
#
# at random state 118,the training accuracy is :0.7522408778256171
# at random state 118,the testing accuracy is :0.7631984176255882
#
#
# at random state 119,the training accuracy is :0.7546318257587458
# at random state 119,the testing accuracy is :0.755395006446038
#
#
# at random state 120,the training accuracy is :0.751347661669178
# at random state 120,the testing accuracy is :0.768967118683586
#
#
# at random state 121,the training accuracy is :0.7543484236431995
# at random state 121,the testing accuracy is :0.7563031636799493
#
#
# at random state 122,the training accuracy is :0.7565566620857554
# at random state 122,the testing accuracy is :0.7463012377871926
#
#
# at random state 123,the training accuracy is :0.7540582199513082
# at random state 123,the testing accuracy is :0.7575401665481055
#
#
# at random state 124,the training accuracy is :0.754000817039369
# at random state 124,the testing accuracy is :0.7579096337264912
#
#
# at random state 125,the training accuracy is :0.7546975057155061
# at random state 125,the testing accuracy is :0.755397213184392
#
#
# at random state 126,the training accuracy is :0.7562719643399258
# at random state 126,the testing accuracy is :0.7480784947930903
#
#
# at random state 127,the training accuracy is :0.7535471206587956
# at random state 127,the testing accuracy is :0.7604963409193511
#
#
# at random state 128,the training accuracy is :0.7590163436177131
# at random state 128,the testing accuracy is :0.7378643863874156
#
#
# at random state 129,the training accuracy is :0.7543226454520804
# at random state 129,the testing accuracy is :0.7563728921079198
#
#
# at random state 130,the training accuracy is :0.7584579130843419
# at random state 130,the testing accuracy is :0.7395042946203874
#
#
# at random state 131,the training accuracy is :0.7541084617532238
# at random state 131,the testing accuracy is :0.7570925152301322
#
#
# at random state 132,the training accuracy is :0.7555845901635022
# at random state 132,the testing accuracy is :0.7514082378278929
#
#
# at random state 133,the training accuracy is :0.7507382989185452
# at random state 133,the testing accuracy is :0.7703672794542792
#
#
# at random state 134,the training accuracy is :0.7580139954626477
# at random state 134,the testing accuracy is :0.7419070452852912
#
#
# at random state 135,the training accuracy is :0.7612052752117872
# at random state 135,the testing accuracy is :0.7266687912951291
#
#
# at random state 136,the training accuracy is :0.7584727601783186
# at random state 136,the testing accuracy is :0.7398897814410446
#
#
# at random state 137,the training accuracy is :0.7580290449581824
# at random state 137,the testing accuracy is :0.7413200380557184
#
#
# at random state 138,the training accuracy is :0.7528285389286132
# at random state 138,the testing accuracy is :0.7628870317410652
#
#
# at random state 139,the training accuracy is :0.7575639545200847
# at random state 139,the testing accuracy is :0.7435316256543474
#
#
# at random state 140,the training accuracy is :0.7588951239416108
# at random state 140,the testing accuracy is :0.7380222553077813
#
#
# at random state 141,the training accuracy is :0.7539748683349228
# at random state 141,the testing accuracy is :0.7581907015358006
#
#
# at random state 142,the training accuracy is :0.7541406836817082
# at random state 142,the testing accuracy is :0.7569238260147116
#
#
# at random state 143,the training accuracy is :0.753162227352608
# at random state 143,the testing accuracy is :0.7608012978552955
#
#
# at random state 144,the training accuracy is :0.7560841648823372
# at random state 144,the testing accuracy is :0.7492016040346938
#
#
# at random state 145,the training accuracy is :0.7537691689824835
# at random state 145,the testing accuracy is :0.758847413556381
#
#
# at random state 146,the training accuracy is :0.7525356655739951
# at random state 146,the testing accuracy is :0.7638281232122468
#
#
# at random state 147,the training accuracy is :0.755665893967735
# at random state 147,the testing accuracy is :0.7518616663895304
#
#
# at random state 148,the training accuracy is :0.7592574227498265
# at random state 148,the testing accuracy is :0.7363382513552557
#
#
# at random state 149,the training accuracy is :0.7540950992636758
# at random state 149,the testing accuracy is :0.7575337923100122
#
#
# at random state 150,the training accuracy is :0.7593212751501683
# at random state 150,the testing accuracy is :0.7362793784645665
#
#
# at random state 151,the training accuracy is :0.7564250349704237
# at random state 151,the testing accuracy is :0.7483110811193494
#
#
# at random state 152,the training accuracy is :0.7512582330825185
# at random state 152,the testing accuracy is :0.7687793597779206
#
#
# at random state 153,the training accuracy is :0.7566195205365139
# at random state 153,the testing accuracy is :0.7463712440967792
#
#
# at random state 154,the training accuracy is :0.7539365871010377
# at random state 154,the testing accuracy is :0.7586512033970263
#
#
# at random state 155,the training accuracy is :0.7543769360065256
# at random state 155,the testing accuracy is :0.756029434960097
#
#
# at random state 156,the training accuracy is :0.7564639657290166
# at random state 156,the testing accuracy is :0.7479067639963253
#
#
# at random state 157,the training accuracy is :0.7549056070530009
# at random state 157,the testing accuracy is :0.754594208222775
#
#
# at random state 158,the training accuracy is :0.755687821193609
# at random state 158,the testing accuracy is :0.7507117137349582
#
#
# at random state 159,the training accuracy is :0.7611981104922045
# at random state 159,the testing accuracy is :0.7269263823810044
#
#
# at random state 160,the training accuracy is :0.747424103581505
# at random state 160,the testing accuracy is :0.7814104223553824
#
#
# at random state 161,the training accuracy is :0.7562546083358161
# at random state 161,the testing accuracy is :0.7478040351336953
#
#
# at random state 162,the training accuracy is :0.7568009361936888
# at random state 162,the testing accuracy is :0.7469351246918051
#
#
# at random state 163,the training accuracy is :0.7533497467285878
# at random state 163,the testing accuracy is :0.7608999121381517
#
#
# at random state 164,the training accuracy is :0.7594635770538924
# at random state 164,the testing accuracy is :0.7352385865249934
#
#
# at random state 165,the training accuracy is :0.7567374666321206
# at random state 165,the testing accuracy is :0.7466080533524293
#
#
# at random state 166,the training accuracy is :0.7538935071495955
# at random state 166,the testing accuracy is :0.7582023340562787
#
#
# at random state 167,the training accuracy is :0.7560448300261813
# at random state 167,the testing accuracy is :0.7500462609415173
#
#
# at random state 168,the training accuracy is :0.7573039530839947
# at random state 168,the testing accuracy is :0.7446521522185374
#
#
# at random state 169,the training accuracy is :0.7545483287580109
# at random state 169,the testing accuracy is :0.7557030456026805
#
#
# at random state 170,the training accuracy is :0.7602984707238073
# at random state 170,the testing accuracy is :0.7324450085742831
#
#
# at random state 171,the training accuracy is :0.7546294838028613
# at random state 171,the testing accuracy is :0.7555313723860851
#
#
# at random state 172,the training accuracy is :0.7546929484465228
# at random state 172,the testing accuracy is :0.75513452070309
#
#
# at random state 173,the training accuracy is :0.7568154646356071
# at random state 173,the testing accuracy is :0.7455593074000453
#
#
# at random state 174,the training accuracy is :0.7564109224781719
# at random state 174,the testing accuracy is :0.7480857210473157
#
#
# at random state 175,the training accuracy is :0.7601214225866563
# at random state 175,the testing accuracy is :0.7338893112601235
#
#
# at random state 176,the training accuracy is :0.7504814867171063
# at random state 176,the testing accuracy is :0.7715262460643895
#
#
# at random state 177,the training accuracy is :0.7562994074266164
# at random state 177,the testing accuracy is :0.748530250405832
#
#
# at random state 178,the training accuracy is :0.756801076908341
# at random state 178,the testing accuracy is :0.7461887072137616
#
#
# at random state 179,the training accuracy is :0.7574857184489991
# at random state 179,the testing accuracy is :0.7434280516772078
#
#
# at random state 180,the training accuracy is :0.7582312647762975
# at random state 180,the testing accuracy is :0.7404313397583153
#
#
# at random state 181,the training accuracy is :0.7530077401187877
# at random state 181,the testing accuracy is :0.7622271376131892
#
#
# at random state 182,the training accuracy is :0.7521435963621101
# at random state 182,the testing accuracy is :0.764379930988434
#
#
# at random state 183,the training accuracy is :0.7568514741618577
# at random state 183,the testing accuracy is :0.7464574339363718
#
#
# at random state 184,the training accuracy is :0.7523287089062973
# at random state 184,the testing accuracy is :0.7643230281809117
#
#
# at random state 185,the training accuracy is :0.7576862000613451
# at random state 185,the testing accuracy is :0.7428697024177852
#
#
# at random state 186,the training accuracy is :0.7568476211560781
# at random state 186,the testing accuracy is :0.7458178804096323
#
#
# at random state 187,the training accuracy is :0.756632609230693
# at random state 187,the testing accuracy is :0.7471290275423412
#
#
# at random state 188,the training accuracy is :0.7603711429898259
# at random state 188,the testing accuracy is :0.7309268064229142
#
#
# at random state 189,the training accuracy is :0.7572179961623456
# at random state 189,the testing accuracy is :0.7445793127746781
#
#
# at random state 190,the training accuracy is :0.7567653955645463
# at random state 190,the testing accuracy is :0.746402358350928
#
#
# at random state 191,the training accuracy is :0.7489365463374614
# at random state 191,the testing accuracy is :0.7770072438052656
#
#
# at random state 192,the training accuracy is :0.7553461059479196
# at random state 192,the testing accuracy is :0.7527178987441896
#
#
# at random state 193,the training accuracy is :0.7534496942368341
# at random state 193,the testing accuracy is :0.7598571681547371
#
#
# at random state 194,the training accuracy is :0.7577255056564282
# at random state 194,the testing accuracy is :0.7414969931855947
#
#
# at random state 195,the training accuracy is :0.7585460452018965
# at random state 195,the testing accuracy is :0.7404845249613746
#
#
# at random state 196,the training accuracy is :0.7522000903965865
# at random state 196,the testing accuracy is :0.7650975771152194
#
#
# at random state 197,the training accuracy is :0.7585319171416207
# at random state 197,the testing accuracy is :0.7394254916832084
#
#
# at random state 198,the training accuracy is :0.7535651298599712
# at random state 198,the testing accuracy is :0.7595549032178728
#
#
# at random state 199,the training accuracy is :0.7499787067791908
# at random state 199,the testing accuracy is :0.7737128695424723
#
#
# at random state 200,the training accuracy is :0.7484189324146753
# at random state 200,the testing accuracy is :0.7799182007134896
#
#
# at random state 201,the training accuracy is :0.7539227317594137
# at random state 201,the testing accuracy is :0.7578672672727318
#
#
# at random state 202,the training accuracy is :0.7553198928744921
# at random state 202,the testing accuracy is :0.7525380062041872
#
#
# at random state 203,the training accuracy is :0.7545580747961604
# at random state 203,the testing accuracy is :0.7556572730377615
#
#
# at random state 204,the training accuracy is :0.7567764384352593
# at random state 204,the testing accuracy is :0.746339155581356
#
#
# at random state 205,the training accuracy is :0.7501883146443009
# at random state 205,the testing accuracy is :0.7721514583899987
#
#
# at random state 206,the training accuracy is :0.7578593147503943
# at random state 206,the testing accuracy is :0.7423744366591551
#
#
# at random state 207,the training accuracy is :0.7504967667107474
# at random state 207,the testing accuracy is :0.7714818266767047
#
#
# at random state 208,the training accuracy is :0.7558848942844112
# at random state 208,the testing accuracy is :0.7506184968737327
#
#
# at random state 209,the training accuracy is :0.7519970779607441
# at random state 209,the testing accuracy is :0.7662847064754803
#
#
# at random state 210,the training accuracy is :0.7569167717106376
# at random state 210,the testing accuracy is :0.7463522148618754
#
#
# at random state 211,the training accuracy is :0.7558396143844736
# at random state 211,the testing accuracy is :0.7507129154052047
#
#
# at random state 212,the training accuracy is :0.7545154784107828
# at random state 212,the testing accuracy is :0.7558555533415757
#
#
# at random state 213,the training accuracy is :0.7552161823429954
# at random state 213,the testing accuracy is :0.7515943101343218
#
#
# at random state 214,the training accuracy is :0.7516897994997046
# at random state 214,the testing accuracy is :0.766584482999654
#
#
# at random state 215,the training accuracy is :0.7537198032597812
# at random state 215,the testing accuracy is :0.7588769503102786
#
#
# at random state 216,the training accuracy is :0.7525614637317974
# at random state 216,the testing accuracy is :0.763468031502468
#
#
# at random state 217,the training accuracy is :0.7562790867893757
# at random state 217,the testing accuracy is :0.7484511855079818
#
#
# at random state 218,the training accuracy is :0.755428213824001
# at random state 218,the testing accuracy is :0.7521714725871553
#
#
# at random state 219,the training accuracy is :0.7545665180844906
# at random state 219,the testing accuracy is :0.7558056059657423
#
#
# at random state 220,the training accuracy is :0.7537260336895903
# at random state 220,the testing accuracy is :0.7594720378337627
#
#
# at random state 221,the training accuracy is :0.760064253060734
# at random state 221,the testing accuracy is :0.7326898494031826
#
#
# at random state 222,the training accuracy is :0.7533683134539796
# at random state 222,the testing accuracy is :0.7609054347673792
#
#
# at random state 223,the training accuracy is :0.7560165771144102
# at random state 223,the testing accuracy is :0.7495244000338019
#
#
# at random state 224,the training accuracy is :0.7535098551777191
# at random state 224,the testing accuracy is :0.7601918913461135
#
#
# at random state 225,the training accuracy is :0.7521336663143781
# at random state 225,the testing accuracy is :0.7660707516797212
#
#
# at random state 226,the training accuracy is :0.7594561147695896
# at random state 226,the testing accuracy is :0.7365983440602641
#
#
# at random state 227,the training accuracy is :0.7586501103370837
# at random state 227,the testing accuracy is :0.7383825623845766
#
#
# at random state 228,the training accuracy is :0.7558477888762076
# at random state 228,the testing accuracy is :0.7505172280751937
#
#
# at random state 229,the training accuracy is :0.7484672489339361
# at random state 229,the testing accuracy is :0.7787751174692321
#
#
# at random state 230,the training accuracy is :0.7593470398610804
# at random state 230,the testing accuracy is :0.7361284182995151
#
#
# at random state 231,the training accuracy is :0.7590816994009101
# at random state 231,the testing accuracy is :0.7363980547706777
#
#
# at random state 232,the training accuracy is :0.7557052140912112
# at random state 232,the testing accuracy is :0.7501474167728681
#
#
# at random state 233,the training accuracy is :0.7580647575476109
# at random state 233,the testing accuracy is :0.7422673495082794
#
#
# at random state 234,the training accuracy is :0.7568719213774084
# at random state 234,the testing accuracy is :0.7466594220060212
#
#
# at random state 235,the training accuracy is :0.7552364396305965
# at random state 235,the testing accuracy is :0.7527151461610445
#
#
# at random state 236,the training accuracy is :0.754920382553004
# at random state 236,the testing accuracy is :0.7540417273765517
#
#
# at random state 237,the training accuracy is :0.751316052686239
# at random state 237,the testing accuracy is :0.7685332637068746
#
#
# at random state 238,the training accuracy is :0.7563711851582301
# at random state 238,the testing accuracy is :0.7484637520152984
#
#
# at random state 239,the training accuracy is :0.7567920376943351
# at random state 239,the testing accuracy is :0.7470762640631068
#
#
# at random state 240,the training accuracy is :0.7519987875681058
# at random state 240,the testing accuracy is :0.7654112602941208
#
#
# at random state 241,the training accuracy is :0.7568245734549691
# at random state 241,the testing accuracy is :0.7451728697884208
#
#
# at random state 242,the training accuracy is :0.7518603083250558
# at random state 242,the testing accuracy is :0.765411108291898
#
#
# at random state 243,the training accuracy is :0.7534690396530231
# at random state 243,the testing accuracy is :0.7602308038091159
#
#
# at random state 244,the training accuracy is :0.7556884175358842
# at random state 244,the testing accuracy is :0.751286151140707
#
#
# at random state 245,the training accuracy is :0.759288976817414
# at random state 245,the testing accuracy is :0.7367891324153448
#
#
# at random state 246,the training accuracy is :0.7551998785575676
# at random state 246,the testing accuracy is :0.7537382778750976
#
#
# at random state 247,the training accuracy is :0.7536836981361721
# at random state 247,the testing accuracy is :0.7597075399391663
#
#
# at random state 248,the training accuracy is :0.7495007578919206
# at random state 248,the testing accuracy is :0.7746268654537396
#
#
# at random state 249,the training accuracy is :0.7573315842429263
# at random state 249,the testing accuracy is :0.7444988610629932
#
#
# at random state 250,the training accuracy is :0.7583597172377966
# at random state 250,the testing accuracy is :0.7397335633118751
#
#
# at random state 251,the training accuracy is :0.7515889666559091
# at random state 251,the testing accuracy is :0.7676975359883367
#
#
# at random state 252,the training accuracy is :0.7556538504508632
# at random state 252,the testing accuracy is :0.7510738972056629
#
#
# at random state 253,the training accuracy is :0.751965495397532
# at random state 253,the testing accuracy is :0.7658509042321503
#
#
# at random state 254,the training accuracy is :0.7538997409244903
# at random state 254,the testing accuracy is :0.7583079256586107
#
#
# at random state 255,the training accuracy is :0.7567031281688811
# at random state 255,the testing accuracy is :0.7469591895305099
#
#
# at random state 256,the training accuracy is :0.756342998956834
# at random state 256,the testing accuracy is :0.7491670084558242
#
#
# at random state 257,the training accuracy is :0.7626347089139458
# at random state 257,the testing accuracy is :0.7216489227716716
#
#
# at random state 258,the training accuracy is :0.7564649515775655
# at random state 258,the testing accuracy is :0.7482780507150444
#
#
# at random state 259,the training accuracy is :0.7533575963376423
# at random state 259,the testing accuracy is :0.7601794133907216
#
#
# at random state 260,the training accuracy is :0.754344061986028
# at random state 260,the testing accuracy is :0.7566270197020177
#
#
# at random state 261,the training accuracy is :0.7549788075041415
# at random state 261,the testing accuracy is :0.754089821789008
#
#
# at random state 262,the training accuracy is :0.7626500020566913
# at random state 262,the testing accuracy is :0.7219186214729023
#
#
# at random state 263,the training accuracy is :0.7542203552196274
# at random state 263,the testing accuracy is :0.7570241325604805
#
#
# at random state 264,the training accuracy is :0.7549695216566209
# at random state 264,the testing accuracy is :0.7536400395371915
#
#
# at random state 265,the training accuracy is :0.7538875167547461
# at random state 265,the testing accuracy is :0.757931279370091
#
#
# at random state 266,the training accuracy is :0.7534304815009079
# at random state 266,the testing accuracy is :0.7597643300619945
#
#
# at random state 267,the training accuracy is :0.7498348682206679
# at random state 267,the testing accuracy is :0.7723164074757618
#
#
# at random state 268,the training accuracy is :0.7542568336183271
# at random state 268,the testing accuracy is :0.7567895289678997
#
#
# at random state 269,the training accuracy is :0.756264389859659
# at random state 269,the testing accuracy is :0.7479227004593723
#
#
# at random state 270,the training accuracy is :0.7551058788379845
# at random state 270,the testing accuracy is :0.7534242747056804
#
#
# at random state 271,the training accuracy is :0.7581884285219403
# at random state 271,the testing accuracy is :0.7412101900450696
#
#
# at random state 272,the training accuracy is :0.7570528904225516
# at random state 272,the testing accuracy is :0.7453148914350163
#
#
# at random state 273,the training accuracy is :0.7585387065908648
# at random state 273,the testing accuracy is :0.7381649924164795
#
#
# at random state 274,the training accuracy is :0.7531805799319994
# at random state 274,the testing accuracy is :0.7610927771068158
#
#
# at random state 275,the training accuracy is :0.7578217192243937
# at random state 275,the testing accuracy is :0.7427347675860445
#
#
# at random state 276,the training accuracy is :0.754213254842547
# at random state 276,the testing accuracy is :0.7571691848984264
#
#
# at random state 277,the training accuracy is :0.7572683235566551
# at random state 277,the testing accuracy is :0.7446152910553152
#
#
# at random state 278,the training accuracy is :0.7595257169364096
# at random state 278,the testing accuracy is :0.7356616535293619
#
#
# at random state 279,the training accuracy is :0.7540108018413998
# at random state 279,the testing accuracy is :0.758328771886467
#
#
# at random state 280,the training accuracy is :0.7519705184517881
# at random state 280,the testing accuracy is :0.7659938096545397
#
#
# at random state 281,the training accuracy is :0.754140665254942
# at random state 281,the testing accuracy is :0.7575042165665573
#
#
# at random state 282,the training accuracy is :0.7539838118838489
# at random state 282,the testing accuracy is :0.7580319434742887
#
#
# at random state 283,the training accuracy is :0.7548846057966968
# at random state 283,the testing accuracy is :0.7545854418093487
#
#
# at random state 284,the training accuracy is :0.7570662699079626
# at random state 284,the testing accuracy is :0.7454924868317524
#
#
# at random state 285,the training accuracy is :0.7581618690294115
# at random state 285,the testing accuracy is :0.7408727430787054
#
#
# at random state 286,the training accuracy is :0.7513877208509723
# at random state 286,the testing accuracy is :0.7677969719993553
#
#
# at random state 287,the training accuracy is :0.7548541827314472
# at random state 287,the testing accuracy is :0.7544566721087631
#
#
# at random state 288,the training accuracy is :0.759604266343072
# at random state 288,the testing accuracy is :0.7346474809444303
#
#
# at random state 289,the training accuracy is :0.7540327076662008
# at random state 289,the testing accuracy is :0.756677673500281
#
#
# at random state 290,the training accuracy is :0.7579028325300441
# at random state 290,the testing accuracy is :0.7424628923947943
#
#
# at random state 291,the training accuracy is :0.7575733529421714
# at random state 291,the testing accuracy is :0.7435743773605389
#
#
# at random state 292,the training accuracy is :0.7509539536538243
# at random state 292,the testing accuracy is :0.7696199401251472
#
#
# at random state 293,the training accuracy is :0.7562082568028201
# at random state 293,the testing accuracy is :0.749675505180275
#
#
# at random state 294,the training accuracy is :0.7582574914746212
# at random state 294,the testing accuracy is :0.7413334844238255
#
#
# at random state 295,the training accuracy is :0.7524851628847518
# at random state 295,the testing accuracy is :0.7631562506826248
#
#
# at random state 296,the training accuracy is :0.7581654593116304
# at random state 296,the testing accuracy is :0.741535929792315
#
#
# at random state 297,the training accuracy is :0.7573372366613856
# at random state 297,the testing accuracy is :0.7437633503958356
#
#
# at random state 298,the training accuracy is :0.757762909415265
# at random state 298,the testing accuracy is :0.7415501126041673
#
#
# at random state 299,the training accuracy is :0.7567812805944079
# at random state 299,the testing accuracy is :0.7468178039127034
#
#
# at random state 300,the training accuracy is :0.757689224287716
# at random state 300,the testing accuracy is :0.7414767708520924
#
#
# at random state 301,the training accuracy is :0.7493704321923618
# at random state 301,the testing accuracy is :0.7763723759171757
#
#
# at random state 302,the training accuracy is :0.7568331073113572
# at random state 302,the testing accuracy is :0.7462556137405443
#
#
# at random state 303,the training accuracy is :0.7530788923137794
# at random state 303,the testing accuracy is :0.7616749928930063
#
#
# at random state 304,the training accuracy is :0.751718188606365
# at random state 304,the testing accuracy is :0.7655988244804446
#
#
# at random state 305,the training accuracy is :0.7586002566400899
# at random state 305,the testing accuracy is :0.7379875124928965
#
#
# at random state 306,the training accuracy is :0.7596740908033162
# at random state 306,the testing accuracy is :0.7346763701711024
#
#
# at random state 307,the training accuracy is :0.7576018308162268
# at random state 307,the testing accuracy is :0.743826240474651
#
#
# at random state 308,the training accuracy is :0.7542167471337917
# at random state 308,the testing accuracy is :0.7566401522730803
#
#
# at random state 309,the training accuracy is :0.7540938372074701
# at random state 309,the testing accuracy is :0.7576777509460699
#
#
# at random state 310,the training accuracy is :0.752868306294556
# at random state 310,the testing accuracy is :0.7626215316156794
#
#
# at random state 311,the training accuracy is :0.7585820444347433
# at random state 311,the testing accuracy is :0.7394986653302928
#
#
# at random state 312,the training accuracy is :0.7538346078747361
# at random state 312,the testing accuracy is :0.7586572510822316
#
#
# at random state 313,the training accuracy is :0.7527006650551626
# at random state 313,the testing accuracy is :0.7631306863311901
#
#
# at random state 314,the training accuracy is :0.7596992155606771
# at random state 314,the testing accuracy is :0.7343334526375264
#
#
# at random state 315,the training accuracy is :0.7522600571482053
# at random state 315,the testing accuracy is :0.7644388478403595
#
#
# at random state 316,the training accuracy is :0.7630378294291675
# at random state 316,the testing accuracy is :0.7213747993934947
#
#
# at random state 317,the training accuracy is :0.7588889104564929
# at random state 317,the testing accuracy is :0.7375592359465358
#
#
# at random state 318,the training accuracy is :0.7507742790231752
# at random state 318,the testing accuracy is :0.7706574014725599
#
#
# at random state 319,the training accuracy is :0.7551572891229732
# at random state 319,the testing accuracy is :0.7530337165113096
#
#
# at random state 320,the training accuracy is :0.7565559291976116
# at random state 320,the testing accuracy is :0.7476086461250011
#
#
# at random state 321,the training accuracy is :0.7478385638091247
# at random state 321,the testing accuracy is :0.7799449528400417
#
#
# at random state 322,the training accuracy is :0.7551065806871682
# at random state 322,the testing accuracy is :0.7530226484479025
#
#
# at random state 323,the training accuracy is :0.7528542190385028
# at random state 323,the testing accuracy is :0.762721146094459
#
#
# at random state 324,the training accuracy is :0.7553220490575144
# at random state 324,the testing accuracy is :0.7524893611712573
#
#
# at random state 325,the training accuracy is :0.7571673902577066
# at random state 325,the testing accuracy is :0.7448015135041675
#
#
# at random state 326,the training accuracy is :0.7566992216710932
# at random state 326,the testing accuracy is :0.7469060046984839
#
#
# at random state 327,the training accuracy is :0.7547651399724247
# at random state 327,the testing accuracy is :0.754428306048212
#
#
# at random state 328,the training accuracy is :0.7535398937992301
# at random state 328,the testing accuracy is :0.7598985883963028
#
#
# at random state 329,the training accuracy is :0.7555352844374746
# at random state 329,the testing accuracy is :0.7516200513111353
#
#
# at random state 330,the training accuracy is :0.7614364415491797
# at random state 330,the testing accuracy is :0.7288497410507992
#
#
# at random state 331,the training accuracy is :0.7592400844436544
# at random state 331,the testing accuracy is :0.7362021769589596
#
#
# at random state 332,the training accuracy is :0.7529262857388377
# at random state 332,the testing accuracy is :0.7624467631759775
#
#
# at random state 333,the training accuracy is :0.7553624281020143
# at random state 333,the testing accuracy is :0.7524476313160714
#
#
# at random state 334,the training accuracy is :0.7588657546447812
# at random state 334,the testing accuracy is :0.7393778306622723
#
#
# at random state 335,the training accuracy is :0.7484196920686377
# at random state 335,the testing accuracy is :0.7796714580550629
#
#
# at random state 336,the training accuracy is :0.7572218954678236
# at random state 336,the testing accuracy is :0.7436968829779128
#
#
# at random state 337,the training accuracy is :0.7555695136181397
# at random state 337,the testing accuracy is :0.7512630760053653
#
#
# at random state 338,the training accuracy is :0.7570378918499763
# at random state 338,the testing accuracy is :0.7457666025082834
#
#
# at random state 339,the training accuracy is :0.753791667526224
# at random state 339,the testing accuracy is :0.758697351456245
#
#
# at random state 340,the training accuracy is :0.756946361036082
# at random state 340,the testing accuracy is :0.746308209104743
#
#
# at random state 341,the training accuracy is :0.7573155080599837
# at random state 341,the testing accuracy is :0.7445069170626816
#
#
# at random state 342,the training accuracy is :0.7552660968166276
# at random state 342,the testing accuracy is :0.7529018734606389
#
#
# at random state 343,the training accuracy is :0.754607243071836
# at random state 343,the testing accuracy is :0.7556188046725462
#
#
# at random state 344,the training accuracy is :0.754912577841464
# at random state 344,the testing accuracy is :0.7544194299948681
#
#
# at random state 345,the training accuracy is :0.7548365449345511
# at random state 345,the testing accuracy is :0.7542074809393369
#
#
# at random state 346,the training accuracy is :0.7560921071419402
# at random state 346,the testing accuracy is :0.7494032771363937
#
#
# at random state 347,the training accuracy is :0.7545910577793674
# at random state 347,the testing accuracy is :0.7554639607849104
#
#
# at random state 348,the training accuracy is :0.7503889975706926
# at random state 348,the testing accuracy is :0.7721115346920913
#
#
# at random state 349,the training accuracy is :0.7518308236499469
# at random state 349,the testing accuracy is :0.7658091374109774
#
#
# at random state 350,the training accuracy is :0.7488009896734331
# at random state 350,the testing accuracy is :0.7777502325551732
#
#
# at random state 351,the training accuracy is :0.7548783533931831
# at random state 351,the testing accuracy is :0.7541504245474696
#
#
# at random state 352,the training accuracy is :0.7569369943140497
# at random state 352,the testing accuracy is :0.7460054680102113
#
#
# at random state 353,the training accuracy is :0.7570626858715942
# at random state 353,the testing accuracy is :0.7450459999524197
#
#
# at random state 354,the training accuracy is :0.7575862042620071
# at random state 354,the testing accuracy is :0.7434804318323384
#
#
# at random state 355,the training accuracy is :0.7556692663865892
# at random state 355,the testing accuracy is :0.7510883663245255
#
#
# at random state 356,the training accuracy is :0.7607637602973437
# at random state 356,the testing accuracy is :0.7284137279579683
#
#
# at random state 357,the training accuracy is :0.7531333004426871
# at random state 357,the testing accuracy is :0.7615692745195581
#
#
# at random state 358,the training accuracy is :0.7554166060506011
# at random state 358,the testing accuracy is :0.752166896646218
#
#
# at random state 359,the training accuracy is :0.7550959720025318
# at random state 359,the testing accuracy is :0.7538093453273422
#
#
# at random state 360,the training accuracy is :0.7556774159807349
# at random state 360,the testing accuracy is :0.7507558796576175
#
#
# at random state 361,the training accuracy is :0.7561260560704608
# at random state 361,the testing accuracy is :0.7496084168316871
#
#
# at random state 362,the training accuracy is :0.7554612657944253
# at random state 362,the testing accuracy is :0.7521013782120252
#
#
# at random state 363,the training accuracy is :0.7530896990041612
# at random state 363,the testing accuracy is :0.7620612644327327
#
#
# at random state 364,the training accuracy is :0.7583366802734854
# at random state 364,the testing accuracy is :0.7401289897333764
#
#
# at random state 365,the training accuracy is :0.7564717701262194
# at random state 365,the testing accuracy is :0.7472518320845843
#
#
# at random state 366,the training accuracy is :0.7568748400785762
# at random state 366,the testing accuracy is :0.7465587298993765
#
#
# at random state 367,the training accuracy is :0.754719999610826
# at random state 367,the testing accuracy is :0.7539510102265535
#
#
# at random state 368,the training accuracy is :0.7540129998774454
# ...
# at random state 1879,the testing accuracy is :0.7582472275344256
#
#
# at random state 1880,the training accuracy is :0.7526439497656012
# at random state 1880,the testing accuracy is :0.7634897285458158
#
#
# at random state 1881,the training accuracy is :0.7566835262992673
# at random state 1881,the testing accuracy is :0.7472404082923882
#
#
# at random state 1882,the training accuracy is :0.7563283973631869
# at random state 1882,the testing accuracy is :0.7483042952283827
#
#
# at random state 1883,the training accuracy is :0.7537177317834332
# at random state 1883,the testing accuracy is :0.7593426806521978
#
#
# at random state 1884,the training accuracy is :0.7494581158009416
# at random state 1884,the testing accuracy is :0.7741407438147566
#
#
# at random state 1885,the training accuracy is :0.7523856199261061
# at random state 1885,the testing accuracy is :0.7645583177148996
#
#
# at random state 1886,the training accuracy is :0.7542669571600705
# at random state 1886,the testing accuracy is :0.7568970643638724
#
#
# at random state 1887,the training accuracy is :0.7560933621855884
# at random state 1887,the testing accuracy is :0.7496669417738571
#
#
# at random state 1888,the training accuracy is :0.7597472379069417
# at random state 1888,the testing accuracy is :0.7358740135309192
#
#
# at random state 1889,the training accuracy is :0.7522151142783253
# at random state 1889,the testing accuracy is :0.7641404969670796
#
#
# at random state 1890,the training accuracy is :0.7525502342831201
# at random state 1890,the testing accuracy is :0.763584303603511
#
#
# at random state 1891,the training accuracy is :0.7521199312589588
# at random state 1891,the testing accuracy is :0.7651630044634
#
#
# at random state 1892,the training accuracy is :0.7555916100897995
# at random state 1892,the testing accuracy is :0.7515897791288355
#
#
# at random state 1893,the training accuracy is :0.7547862304979642
# at random state 1893,the testing accuracy is :0.7545373150372505
#
#
# at random state 1894,the training accuracy is :0.7555867007055294
# at random state 1894,the testing accuracy is :0.7513666371557151
#
#
# at random state 1895,the training accuracy is :0.7494983067978738
# at random state 1895,the testing accuracy is :0.7755224132151107
#
#
# at random state 1896,the training accuracy is :0.7540587688986526
# at random state 1896,the testing accuracy is :0.7578362564844139
#
#
# at random state 1897,the training accuracy is :0.7588176369789716
# at random state 1897,the testing accuracy is :0.7388138117107892
#
#
# at random state 1898,the training accuracy is :0.7564467990100752
# at random state 1898,the testing accuracy is :0.7484688332797884
#
#
# at random state 1899,the training accuracy is :0.76145894832598
# at random state 1899,the testing accuracy is :0.72806866417595
#
#
# at random state 1900,the training accuracy is :0.7565945514726885
# at random state 1900,the testing accuracy is :0.7469523591106006
#
#
# at random state 1901,the training accuracy is :0.7579050850632577
# at random state 1901,the testing accuracy is :0.7418081531919729
#
#
# at random state 1902,the training accuracy is :0.7566487648129369
# at random state 1902,the testing accuracy is :0.7470074014263804
#
#
# at random state 1903,the training accuracy is :0.7535975451786769
# at random state 1903,the testing accuracy is :0.7594401483249338
#
#
# at random state 1904,the training accuracy is :0.758288465341266
# at random state 1904,the testing accuracy is :0.7409217939574255
#
#
# at random state 1905,the training accuracy is :0.7515714574937067
# at random state 1905,the testing accuracy is :0.7672246719291762
#
#
# at random state 1906,the training accuracy is :0.756380117722107
# at random state 1906,the testing accuracy is :0.7487734756094031
#
#
# at random state 1907,the training accuracy is :0.7529288566325403
# at random state 1907,the testing accuracy is :0.7605475433336041
#
#
# at random state 1908,the training accuracy is :0.7560293001916736
# at random state 1908,the testing accuracy is :0.7504890009965085
#
#
# at random state 1909,the training accuracy is :0.7566074940224922
# at random state 1909,the testing accuracy is :0.7464701966966105
#
#
# at random state 1910,the training accuracy is :0.7586320849113689
# at random state 1910,the testing accuracy is :0.7380245500220535
#
#
# at random state 1911,the training accuracy is :0.7592433957907162
# at random state 1911,the testing accuracy is :0.7354772152002251
#
#
# at random state 1912,the training accuracy is :0.7543777513568417
# at random state 1912,the testing accuracy is :0.7564062513048783
#
#
# at random state 1913,the training accuracy is :0.7540024826168782
# at random state 1913,the testing accuracy is :0.7574890381376681
#
#
# at random state 1914,the training accuracy is :0.7529571272638715
# at random state 1914,the testing accuracy is :0.7623427290360105
#
#
# at random state 1915,the training accuracy is :0.7529022994796885
# at random state 1915,the testing accuracy is :0.7619159109721008
#
#
# at random state 1916,the training accuracy is :0.7473960038348022
# at random state 1916,the testing accuracy is :0.7835114990813861
#
#
# at random state 1917,the training accuracy is :0.7604708265746647
# at random state 1917,the testing accuracy is :0.7300725148648068
#
#
# at random state 1918,the training accuracy is :0.7589677734964275
# at random state 1918,the testing accuracy is :0.7369767080247436
#
#
# at random state 1919,the training accuracy is :0.7542313662975697
# at random state 1919,the testing accuracy is :0.7557497549428501
#
#
# at random state 1920,the training accuracy is :0.7565562138726855
# at random state 1920,the testing accuracy is :0.7475434705361584
#
#
# at random state 1921,the training accuracy is :0.7556358270343353
# at random state 1921,the testing accuracy is :0.750346729100642
#
#
# at random state 1922,the training accuracy is :0.7525427464198944
# at random state 1922,the testing accuracy is :0.7637288890625797
#
#
# at random state 1923,the training accuracy is :0.7492101622714917
# at random state 1923,the testing accuracy is :0.7758427505510677
#
#
# at random state 1924,the training accuracy is :0.7584283357709264
# at random state 1924,the testing accuracy is :0.7403559448449373
#
#
# at random state 1925,the training accuracy is :0.7543705552976362
# at random state 1925,the testing accuracy is :0.7558201740241528
#
#
# at random state 1926,the training accuracy is :0.7581036752157121
# at random state 1926,the testing accuracy is :0.7412817658938786
#
#
# at random state 1927,the training accuracy is :0.7562634219129412
# at random state 1927,the testing accuracy is :0.7493384413438307
#
#
# at random state 1928,the training accuracy is :0.7556045808654435
# at random state 1928,the testing accuracy is :0.7513352284201988
#
#
# at random state 1929,the training accuracy is :0.7569655969513999
# at random state 1929,the testing accuracy is :0.7462487617726257
#
#
# at random state 1930,the training accuracy is :0.7544510562759338
# at random state 1930,the testing accuracy is :0.7564693089909512
#
#
# at random state 1931,the training accuracy is :0.75446001701588
# at random state 1931,the testing accuracy is :0.7559902294484052
#
#
# at random state 1932,the training accuracy is :0.7547349758871434
# at random state 1932,the testing accuracy is :0.7554272860256528
#
#
# at random state 1933,the training accuracy is :0.7520233083528299
# at random state 1933,the testing accuracy is :0.7659466700334672
#
#
# at random state 1934,the training accuracy is :0.7577858344649618
# at random state 1934,the testing accuracy is :0.7422544644403971
#
#
# at random state 1935,the training accuracy is :0.7561861905546449
# at random state 1935,the testing accuracy is :0.7492949686544255
#
#
# at random state 1936,the training accuracy is :0.7579675992914604
# at random state 1936,the testing accuracy is :0.7417279638239661
#
#
# at random state 1937,the training accuracy is :0.7523147525326715
# at random state 1937,the testing accuracy is :0.7639645763848403
#
#
# at random state 1938,the training accuracy is :0.7517175254450699
# at random state 1938,the testing accuracy is :0.766843136578612
#
#
# at random state 1939,the training accuracy is :0.7557510245998067
# at random state 1939,the testing accuracy is :0.7506324865213575
#
#
# at random state 1940,the training accuracy is :0.7539113954524836
# at random state 1940,the testing accuracy is :0.7583587745931829
#
#
# at random state 1941,the training accuracy is :0.7578203576552685
# at random state 1941,the testing accuracy is :0.7419735762227391
#
#
# at random state 1942,the training accuracy is :0.7549139078354759
# at random state 1942,the testing accuracy is :0.7541702253288366
#
#
# at random state 1943,the training accuracy is :0.7577148384870065
# at random state 1943,the testing accuracy is :0.7430100275333233
#
#
# at random state 1944,the training accuracy is :0.7592074426651512
# at random state 1944,the testing accuracy is :0.7348662867536905
#
#
# at random state 1945,the training accuracy is :0.7556233916085602
# at random state 1945,the testing accuracy is :0.7515178009198207
#
#
# at random state 1946,the training accuracy is :0.7566172244238856
# at random state 1946,the testing accuracy is :0.7476649758996217
#
#
# at random state 1947,the training accuracy is :0.7538504244846684
# at random state 1947,the testing accuracy is :0.7587299639535743
#
#
# at random state 1948,the training accuracy is :0.7569862018314781
# at random state 1948,the testing accuracy is :0.7456532960381564
#
#
# at random state 1949,the training accuracy is :0.7562063448133226
# at random state 1949,the testing accuracy is :0.7495031147742723
#
#
# at random state 1950,the training accuracy is :0.7539139073077266
# at random state 1950,the testing accuracy is :0.7584723946192299
#
#
# at random state 1951,the training accuracy is :0.7608945102984581
# at random state 1951,the testing accuracy is :0.7296772035891166
#
#
# at random state 1952,the training accuracy is :0.7576448214297511
# at random state 1952,the testing accuracy is :0.7432391227010249
#
#
# at random state 1953,the training accuracy is :0.7530732358451732
# at random state 1953,the testing accuracy is :0.762098387396292
#
#
# at random state 1954,the training accuracy is :0.7553986237125095
# at random state 1954,the testing accuracy is :0.7523681974891563
#
#
# at random state 1955,the training accuracy is :0.7541062965496194
# at random state 1955,the testing accuracy is :0.7565951667040314
#
#
# at random state 1956,the training accuracy is :0.7531325769566581
# at random state 1956,the testing accuracy is :0.7609159000045546
#
#
# at random state 1957,the training accuracy is :0.755004737848542
# at random state 1957,the testing accuracy is :0.7536867052173909
#
#
# at random state 1958,the training accuracy is :0.75603848733297
# at random state 1958,the testing accuracy is :0.7495722178447023
#
#
# at random state 1959,the training accuracy is :0.7568756743754101
# at random state 1959,the testing accuracy is :0.7456905185003213
#
#
# at random state 1960,the training accuracy is :0.7575882659482738
# at random state 1960,the testing accuracy is :0.7437740008655687
#
#
# at random state 1961,the training accuracy is :0.7518750963254925
# at random state 1961,the testing accuracy is :0.765194200756698
#
#
# at random state 1962,the training accuracy is :0.7598674991768258
# at random state 1962,the testing accuracy is :0.7342058216900396
#
#
# at random state 1963,the training accuracy is :0.7567394492848762
# at random state 1963,the testing accuracy is :0.7466774552545102
#
#
# at random state 1964,the training accuracy is :0.7568416239514661
# at random state 1964,the testing accuracy is :0.7459875009781765
#
#
# at random state 1965,the training accuracy is :0.7570465217526823
# at random state 1965,the testing accuracy is :0.7452670091684498
#
#
# at random state 1966,the training accuracy is :0.7570401624480413
# at random state 1966,the testing accuracy is :0.745233654573083
#
#
# at random state 1967,the training accuracy is :0.7555469913115137
# at random state 1967,the testing accuracy is :0.7512609312180971
#
#
# at random state 1968,the training accuracy is :0.7604766641786046
# at random state 1968,the testing accuracy is :0.7309484884396652
#
#
# at random state 1969,the training accuracy is :0.760298841531538
# at random state 1969,the testing accuracy is :0.7320752978460453
#
#
# at random state 1970,the training accuracy is :0.7531133428622496
# at random state 1970,the testing accuracy is :0.7614147437180281
#
#
# at random state 1971,the training accuracy is :0.7569369715825063
# at random state 1971,the testing accuracy is :0.7470227507086157
#
#
# at random state 1972,the training accuracy is :0.7535141623159635
# at random state 1972,the testing accuracy is :0.7592653446918447
#
#
# at random state 1973,the training accuracy is :0.7585222201895518
# at random state 1973,the testing accuracy is :0.7394538778062969
#
#
# at random state 1974,the training accuracy is :0.7537709651956102
# at random state 1974,the testing accuracy is :0.7591759321475364
#
#
# at random state 1975,the training accuracy is :0.7570278108699622
# at random state 1975,the testing accuracy is :0.7466180029530871
#
#
# at random state 1976,the training accuracy is :0.755087769834406
# at random state 1976,the testing accuracy is :0.7539762164177334
#
#
# at random state 1977,the training accuracy is :0.7567855725910142
# at random state 1977,the testing accuracy is :0.7467064881379044
#
#
# at random state 1978,the training accuracy is :0.7567695362870178
# at random state 1978,the testing accuracy is :0.7458815307871529
#
#
# at random state 1979,the training accuracy is :0.7504218856018932
# at random state 1979,the testing accuracy is :0.7713763777911475
#
#
# at random state 1980,the training accuracy is :0.7529990375648312
# at random state 1980,the testing accuracy is :0.7605256278432753
#
#
# at random state 1981,the training accuracy is :0.7522741579236938
# at random state 1981,the testing accuracy is :0.7639862217306463
#
#
# at random state 1982,the training accuracy is :0.757334633153293
# at random state 1982,the testing accuracy is :0.7438436696070854
#
#
# at random state 1983,the training accuracy is :0.7601832461653764
# at random state 1983,the testing accuracy is :0.73239239649204
#
#
# at random state 1984,the training accuracy is :0.7537916753556554
# at random state 1984,the testing accuracy is :0.7588984745294732
#
#
# at random state 1985,the training accuracy is :0.7575860979900921
# at random state 1985,the testing accuracy is :0.7440324257216957
#
#
# at random state 1986,the training accuracy is :0.7544381726514993
# at random state 1986,the testing accuracy is :0.7560621997600523
#
#
# at random state 1987,the training accuracy is :0.754469537187312
# at random state 1987,the testing accuracy is :0.7560534319185096
#
#
# at random state 1988,the training accuracy is :0.7554490106053104
# at random state 1988,the testing accuracy is :0.7525214759456469
#
#
# at random state 1989,the training accuracy is :0.754346083890954
# at random state 1989,the testing accuracy is :0.7570144067670271
#
#
# at random state 1990,the training accuracy is :0.7490004737271819
# at random state 1990,the testing accuracy is :0.7770238444649002
#
#
# at random state 1991,the training accuracy is :0.757149281043047
# at random state 1991,the testing accuracy is :0.7460016653646209
#
#
# at random state 1992,the training accuracy is :0.7560500347383818
# at random state 1992,the testing accuracy is :0.7494319468494504
#
#
# at random state 1993,the training accuracy is :0.753640925886764
# at random state 1993,the testing accuracy is :0.7595399225312727
#
#
# at random state 1994,the training accuracy is :0.7459470844031408
# at random state 1994,the testing accuracy is :0.7879955616650804
#
#
# at random state 1995,the training accuracy is :0.7517694714691473
# at random state 1995,the testing accuracy is :0.7664315853074942
#
#
# at random state 1996,the training accuracy is :0.7522533165852797
# at random state 1996,the testing accuracy is :0.7646859432593057
#
#
# at random state 1997,the training accuracy is :0.7502892044387408
# at random state 1997,the testing accuracy is :0.7725061732423344
#
#
# at random state 1998,the training accuracy is :0.7573468945987563
# at random state 1998,the testing accuracy is :0.7453411387815754
#
#
# at random state 1999,the training accuracy is :0.7592689533248889
# at random state 1999,the testing accuracy is :0.7363174986928427

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=49)

# %%
x_train.shape
# Out:
# (6201, 21)

# %%
y_train.shape
# Out:
# (6201,)

# %%
x_test.shape
# Out:
# (1551, 21)

# %%
y_test.shape
# Out:
# (1551,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.7544579108335454

# %% [markdown]
# # CROSS VALIDATION

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and accuracy score for testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.6638830697238899 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454
#
#
# At cross fold 3 the cv score is 0.6953525353039524 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454
#
#
# At cross fold 4 the cv score is 0.6876082370541621 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454
#
#
# At cross fold 5 the cv score is 0.6846140386859341 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454
#
#
# At cross fold 6 the cv score is 0.6823242433145137 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454
#
#
# At cross fold 7 the cv score is 0.6806614726855161 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454
#
#
# At cross fold 8 the cv score is 0.6726264511254625 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454
#
#
# At cross fold 9 the cv score is 0.6002363204029397 and accuracy score for training is -0.7710415583014409and accuracy score for testing is 0.7544579108335454

# %% [markdown]
# # Plot the Data

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.title("Linear Regression")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.754455692728547

# %%
cv_score=cross_val_score(ls,x,y,cv=3)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.6953889719029056

# %% [markdown]
# # Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)


rfs=r2_score(y_test,pred_decision)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=3)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 score: 90.27081474662658
# Cross Val Score: 68.5680043204119

# %%
import pickle

# %%
filename='Next_Tmax.pkl'
pickle.dump(rf, open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
loaded_model= pickle.load(open('Next_Tmax.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.9027081474662658

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["predicted","original"])
conclusion
# Out:
#              0       1          2          3     4       5      6       7     \
# predicted  34.775  30.163  28.072247  29.762749  31.2  33.029  30.11  30.162
# original   34.775  30.163  28.072247  29.762749  31.2  33.029  30.11  30.162
#
#              8      9     ...    1541    1542    1543    1544    1545    1546  \
# predicted  25.857  23.99  ...  32.313  34.696  27.648  33.516  25.575  32.739
# original   25.857  23.99  ...  32.313  34.696  27.648  33.516  25.575  32.739
#
#              1547       1548    1549       1550
# predicted  30.195  26.557498  25.284  32.010749
# original   30.195  26.557498  25.284  32.010749
#
# [2 rows x 1551 columns]

# %%
tx=at.drop("Next_Tmax",axis=1)

# %%
tx
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0             28.7          21.4    58.255688    91.116364         28.074101
# 1             31.9          21.6    52.263397    90.604721         29.850689
# 2             31.6          23.3    48.690479    83.973587         30.091292
# 3             32.0          23.4    58.239788    96.483688         29.704629
# 4             31.4          21.9    56.174095    90.155128         29.113934
# ...            ...           ...          ...          ...               ...
# 7747          23.3          17.1    26.741310    78.869858         26.352081
# 7748          23.3          17.7    24.040634    77.294975         27.010193
# 7749          23.2          17.4    22.933014    77.243744         27.939516
# 7750          20.0          11.3    19.794666    58.936283         17.624954
# 7751          37.6          29.9    98.524734   100.000153         38.542255
#
#       LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            23.006936   6.818887   69.451805   0.233947   0.203896  ...
# 1            24.035009   5.691890   51.937448   0.225508   0.251771  ...
# 2            24.565633   6.138224   20.573050   0.209344   0.257469  ...
# 3            23.326177   5.650050   65.727144   0.216372   0.226002  ...
# 4            23.486480   5.735004  107.965535   0.151407   0.249995  ...
# ...                ...        ...         ...        ...        ...  ...
# 7747         18.775678   6.148918   72.058294   0.030034   0.081035  ...
# 7748         18.733519   6.542819   47.241457   0.035874   0.074962  ...
# 7749         18.522965   7.289264    9.090034   0.048954   0.059869  ...
# 7750         14.272646   2.882580  -13.603212   0.000000   0.000000  ...
# 7751         29.619342  21.857621  213.414006   0.967277   0.968353  ...
#
#       LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon  \
# 0       0.000000    0.000000    0.000000    0.000000  37.6046  126.991
# 1       0.000000    0.000000    0.000000    0.000000  37.6046  127.032
# 2       0.000000    0.000000    0.000000    0.000000  37.5776  127.058
# 3       0.000000    0.000000    0.000000    0.000000  37.6450  127.022
# 4       0.000000    0.000000    0.000000    0.000000  37.5507  127.135
# ...          ...         ...         ...         ...      ...      ...
# 7747    0.000000    0.000000    0.000000    0.000000  37.5372  126.891
# 7748    0.000000    0.000000    0.000000    0.000000  37.5237  126.909
# 7749    0.000000    0.000000    0.000000    0.000000  37.5237  126.970
# 7750    0.000000    0.000000    0.000000    0.000000  37.4562  126.826
# 7751   23.701544   21.621661   15.841235   16.655469  37.6450  127.135
#
#            DEM     Slope  Solar radiation  Next_Tmin
# 0     212.3350  2.785000      5992.895996       21.2
# 1      44.7624  0.514100      5869.312500       22.5
# 2      33.3068  0.266100      5863.555664       23.9
# 3      45.7160  2.534800      5856.964844       24.3
# 4      35.0380  0.505500      5859.552246       22.5
# ...        ...       ...              ...        ...
# 7747   15.5876  0.155400      4443.313965       18.1
# 7748   17.2956  0.222300      4438.373535       18.8
# 7749   19.5844  0.271300      4451.345215       17.4
# 7750   12.3700  0.098475      4329.520508       11.3
# 7751  212.3350  5.178230      5992.895996       29.8
#
# [7752 rows x 22 columns]

# %%
tx.corr()
# Out:
#                   Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Present_Tmax          1.000000      0.618760    -0.204571    -0.301787
# Present_Tmin          0.618760      1.000000     0.123143    -0.015140
# LDAPS_RHmin          -0.204571      0.123143     1.000000     0.579141
# LDAPS_RHmax          -0.301787     -0.015140     0.579141     1.000000
# LDAPS_Tmax_lapse      0.570129      0.464151    -0.564580    -0.373404
# LDAPS_Tmin_lapse      0.623496      0.762993     0.089476    -0.114143
# LDAPS_WS             -0.121820     -0.034675     0.294361     0.135333
# LDAPS_LH              0.135463     -0.009258    -0.070858     0.238579
# LDAPS_CC1            -0.311805      0.084447     0.613818     0.436652
# LDAPS_CC2            -0.213791      0.090263     0.745443     0.391330
# LDAPS_CC3            -0.144018     -0.002772     0.689679     0.226957
# LDAPS_CC4            -0.140729     -0.044335     0.514075     0.130619
# LDAPS_PPT1           -0.109006      0.112845     0.262665     0.268449
# LDAPS_PPT2           -0.099449      0.068176     0.390967     0.229050
# LDAPS_PPT3           -0.120367     -0.046126     0.240642     0.134607
# LDAPS_PPT4           -0.099607     -0.062965     0.168595     0.117853
# lat                  -0.052615     -0.078475     0.087099     0.195798
# lon                   0.009020     -0.043461    -0.076237     0.025667
# DEM                  -0.187121     -0.250275     0.102115     0.177168
# Slope                -0.105809     -0.146339     0.123744     0.219599
# Solar radiation      -0.025439      0.053578     0.244080     0.149261
# Next_Tmin             0.622741      0.796670     0.095019    -0.071997
#
#                   LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  \
# Present_Tmax              0.570129          0.623496 -0.121820  0.135463
# Present_Tmin              0.464151          0.762993 -0.034675 -0.009258
# LDAPS_RHmin              -0.564580          0.089476  0.294361 -0.070858
# LDAPS_RHmax              -0.373404         -0.114143  0.135333  0.238579
# LDAPS_Tmax_lapse          1.000000          0.654021 -0.311996  0.048010
# LDAPS_Tmin_lapse          0.654021          1.000000 -0.130035 -0.134761
# LDAPS_WS                 -0.311996         -0.130035  1.000000  0.006711
# LDAPS_LH                  0.048010         -0.134761  0.006711  1.000000
# LDAPS_CC1                -0.438439          0.010901  0.289445 -0.147296
# LDAPS_CC2                -0.523619          0.047727  0.261090 -0.264280
# LDAPS_CC3                -0.541327         -0.044018  0.242991 -0.245583
# LDAPS_CC4                -0.429539         -0.080335  0.220533 -0.172766
# LDAPS_PPT1               -0.111065          0.038056  0.152587 -0.012542
# LDAPS_PPT2               -0.242122          0.000870  0.191886 -0.077545
# LDAPS_PPT3               -0.188115         -0.088575  0.161684  0.016102
# LDAPS_PPT4               -0.160273         -0.094655  0.144085  0.019979
# lat                      -0.042093         -0.096257  0.036657  0.133221
# lon                       0.090666         -0.026701 -0.059466  0.025822
# DEM                      -0.178895         -0.195455  0.191053  0.055133
# Slope                    -0.162332         -0.185849  0.171629  0.086781
# Solar radiation           0.047971          0.159975  0.121759 -0.047384
# Next_Tmin                 0.586868          0.880176 -0.096576 -0.055440
#
#                   LDAPS_CC1  LDAPS_CC2  ...  LDAPS_PPT1  LDAPS_PPT2  \
# Present_Tmax      -0.311805  -0.213791  ...   -0.109006   -0.099449
# Present_Tmin       0.084447   0.090263  ...    0.112845    0.068176
# LDAPS_RHmin        0.613818   0.745443  ...    0.262665    0.390967
# LDAPS_RHmax        0.436652   0.391330  ...    0.268449    0.229050
# LDAPS_Tmax_lapse  -0.438439  -0.523619  ...   -0.111065   -0.242122
# LDAPS_Tmin_lapse   0.010901   0.047727  ...    0.038056    0.000870
# LDAPS_WS           0.289445   0.261090  ...    0.152587    0.191886
# LDAPS_LH          -0.147296  -0.264280  ...   -0.012542   -0.077545
# LDAPS_CC1          1.000000   0.779683  ...    0.446328    0.389453
# LDAPS_CC2          0.779683   1.000000  ...    0.305975    0.478472
# LDAPS_CC3          0.517493   0.725813  ...    0.159280    0.337569
# LDAPS_CC4          0.361046   0.527708  ...    0.120483    0.288195
# LDAPS_PPT1         0.446328   0.305975  ...    1.000000    0.383831
# LDAPS_PPT2         0.389453   0.478472  ...    0.383831    1.000000
# LDAPS_PPT3         0.168742   0.240134  ...    0.033004    0.221172
# LDAPS_PPT4         0.091722   0.159548  ...    0.024626    0.139555
# lat               -0.008131  -0.001497  ...    0.000565    0.019564
# lon               -0.006843  -0.003581  ...   -0.001225    0.018600
# DEM               -0.014090  -0.012823  ...    0.011290    0.008357
# Slope             -0.020752  -0.018073  ...    0.016310    0.010214
# Solar radiation    0.218309   0.170403  ...    0.088015    0.110182
# Next_Tmin         -0.011028   0.031250  ...    0.021323   -0.008058
#
#                   LDAPS_PPT3  LDAPS_PPT4       lat       lon       DEM  \
# Present_Tmax       -0.120367   -0.099607 -0.052615  0.009020 -0.187121
# Present_Tmin       -0.046126   -0.062965 -0.078475 -0.043461 -0.250275
# LDAPS_RHmin         0.240642    0.168595  0.087099 -0.076237  0.102115
# LDAPS_RHmax         0.134607    0.117853  0.195798  0.025667  0.177168
# LDAPS_Tmax_lapse   -0.188115   -0.160273 -0.042093  0.090666 -0.178895
# LDAPS_Tmin_lapse   -0.088575   -0.094655 -0.096257 -0.026701 -0.195455
# LDAPS_WS            0.161684    0.144085  0.036657 -0.059466  0.191053
# LDAPS_LH            0.016102    0.019979  0.133221  0.025822  0.055133
# LDAPS_CC1           0.168742    0.091722 -0.008131 -0.006843 -0.014090
# LDAPS_CC2           0.240134    0.159548 -0.001497 -0.003581 -0.012823
# LDAPS_CC3           0.339800    0.302357  0.004108  0.016041  0.000697
# LDAPS_CC4           0.267494    0.376049 -0.009107 -0.002477 -0.007334
# LDAPS_PPT1          0.033004    0.024626  0.000565 -0.001225  0.011290
# LDAPS_PPT2          0.221172    0.139555  0.019564  0.018600  0.008357
# LDAPS_PPT3          1.000000    0.309076  0.035110  0.021662  0.017186
# LDAPS_PPT4          0.309076    1.000000  0.013210  0.044746 -0.003622
# lat                 0.035110    0.013210  1.000000  0.289029  0.033165
# lon                 0.021662    0.044746  0.289029  1.000000  0.007587
# DEM                 0.017186   -0.003622  0.033165  0.007587  1.000000
# Slope               0.025333    0.000117  0.074763  0.038070  0.783576
# Solar radiation    -0.054071    0.034958  0.038513  0.002182  0.056224
# Next_Tmin          -0.062622   -0.103682 -0.083533 -0.046603 -0.246906
#
#                      Slope  Solar radiation  Next_Tmin
# Present_Tmax     -0.105809        -0.025439   0.622741
# Present_Tmin     -0.146339         0.053578   0.796670
# LDAPS_RHmin       0.123744         0.244080   0.095019
# LDAPS_RHmax       0.219599         0.149261  -0.071997
# LDAPS_Tmax_lapse -0.162332         0.047971   0.586868
# LDAPS_Tmin_lapse -0.185849         0.159975   0.880176
# LDAPS_WS          0.171629         0.121759  -0.096576
# LDAPS_LH          0.086781        -0.047384  -0.055440
# LDAPS_CC1        -0.020752         0.218309  -0.011028
# LDAPS_CC2        -0.018073         0.170403   0.031250
# LDAPS_CC3        -0.003338         0.119292  -0.054726
# LDAPS_CC4        -0.014459         0.119983  -0.085093
# LDAPS_PPT1        0.016310         0.088015   0.021323
# LDAPS_PPT2        0.010214         0.110182  -0.008058
# LDAPS_PPT3        0.025333        -0.054071  -0.062622
# LDAPS_PPT4        0.000117         0.034958  -0.103682
# lat               0.074763         0.038513  -0.083533
# lon               0.038070         0.002182  -0.046603
# DEM               0.783576         0.056224  -0.246906
# Slope             1.000000         0.028199  -0.146882
# Solar radiation   0.028199         1.000000   0.120212
# Next_Tmin        -0.146882         0.120212   1.000000
#
# [22 rows x 22 columns]

# %%
tx.corr()['Next_Tmin'].sort_values(ascending=False)
# Out:
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.880176
# Present_Tmin        0.796670
# Present_Tmax        0.622741
# LDAPS_Tmax_lapse    0.586868
# Solar radiation     0.120212
# LDAPS_RHmin         0.095019
# LDAPS_CC2           0.031250
# LDAPS_PPT1          0.021323
# LDAPS_PPT2         -0.008058
# LDAPS_CC1          -0.011028
# lon                -0.046603
# LDAPS_CC3          -0.054726
# LDAPS_LH           -0.055440
# LDAPS_PPT3         -0.062622
# LDAPS_RHmax        -0.071997
# lat                -0.083533
# LDAPS_CC4          -0.085093
# LDAPS_WS           -0.096576
# LDAPS_PPT4         -0.103682
# Slope              -0.146882
# DEM                -0.246906
# Name: Next_Tmin, dtype: float64

# %%
import matplotlib.pyplot as plt  
plt.figure(figsize=(15,7))
sns.heatmap(tx.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
tx.describe()
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7752.000000   7752.000000  7752.000000  7752.000000       7752.000000
# mean      29.768211     23.225059    56.759372    88.374804         29.613447
# std        2.956557      2.403036    14.596973     7.157124          2.932898
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.700000    46.046162    84.316923         27.693091
# 50%       29.900000     23.400000    55.313244    89.699505         29.662273
# 75%       32.000000     24.900000    67.038254    93.704500         31.683819
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean          23.512589     7.097875    62.505019     0.368774     0.356080
# std            2.333973     2.173245    33.567001     0.261185     0.256810
# min           14.272646     2.882580   -13.603212     0.000000     0.000000
# 25%           22.114651     5.686487    37.532764     0.148321     0.142328
# 50%           23.735942     6.563068    57.310630     0.320110     0.315667
# 75%           25.134000     8.007471    83.904586     0.571696     0.554963
# max           29.619342    21.857621   213.414006     0.967277     0.968353
#
#        ...   LDAPS_PPT1   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  ...  7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean   ...     0.591995     0.485003     0.278200     0.269407    37.544722
# std    ...     1.936331     1.754258     1.156174     1.200364     0.050352
# min    ...     0.000000     0.000000     0.000000     0.000000    37.456200
# 25%    ...     0.000000     0.000000     0.000000     0.000000    37.510200
# 50%    ...     0.000000     0.000000     0.000000     0.000000    37.550700
# 75%    ...     0.067593     0.024276     0.009697     0.000693    37.577600
# max    ...    23.701544    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmin
# count  7752.000000  7752.000000  7752.000000      7752.000000  7752.000000
# mean    126.991397    61.867972     1.257048      5341.502803    22.932220
# std       0.079435    54.279780     1.370444       429.158867     2.483276
# min     126.826000    12.370000     0.098475      4329.520508    11.300000
# 25%     126.937000    28.700000     0.271300      4999.018555    21.400000
# 50%     126.995000    45.716000     0.618000      5436.345215    23.100000
# 75%     127.042000    59.832400     1.767800      5728.316406    24.600000
# max     127.135000   212.335000     5.178230      5992.895996    29.800000
#
# [8 rows x 22 columns]

# %%
tx.plot(kind='density',subplots=True,layout=(6,6),sharex=False,legend=False, fontsize=1,figsize=(18,12))
plt.show()

# %%
x=tx.drop("Next_Tmin",axis=1)
y=tx["Next_Tmin"]

# %%
x.skew().sort_values(ascending=False)
# Out:
# LDAPS_PPT4          6.825464
# LDAPS_PPT3          6.457129
# LDAPS_PPT2          5.775355
# LDAPS_PPT1          5.393821
# DEM                 1.723257
# LDAPS_WS            1.579236
# Slope               1.563020
# LDAPS_LH            0.673757
# LDAPS_CC4           0.666482
# LDAPS_CC3           0.640735
# LDAPS_CC2           0.472350
# LDAPS_CC1           0.459458
# LDAPS_RHmin         0.300220
# lat                 0.087062
# LDAPS_Tmax_lapse   -0.227880
# Present_Tmax       -0.264137
# lon                -0.285213
# Present_Tmin       -0.367538
# Solar radiation    -0.511210
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_RHmax        -0.855015
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.408897     -0.797707     0.172680     0.272915         -0.556645
# 1         0.705123     -0.720130    -0.241770     0.185831          0.043756
# 2         0.595692     -0.027674    -0.501459    -0.773454          0.127214
# 3         0.741829      0.014910     0.171612     1.316777         -0.006660
# 4         0.523313     -0.602237     0.031496     0.110968         -0.208627
# ...            ...           ...          ...          ...               ...
# 7747     -2.023162     -2.270927    -2.395892    -1.326845         -1.111724
# 7748     -2.023162     -2.087438    -2.681557    -1.470235         -0.902733
# 7749     -2.049920     -2.180066    -2.803707    -1.474702         -0.600985
# 7750     -2.846187     -3.688005    -3.168120    -2.459357         -3.504186
# 7751      2.981037      3.233078     2.489550     2.143982          3.376037
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            -0.312411  0.093387  0.310382  -0.412176  -0.506509  ...
# 1             0.144368 -0.625565 -0.211695  -0.451258  -0.283702  ...
# 2             0.394571 -0.314874 -1.375126  -0.527382  -0.258127  ...
# 3            -0.174463 -0.656732  0.204179  -0.494077  -0.401828  ...
# 4            -0.103881 -0.593836  1.300503  -0.814752  -0.291713  ...
# ...                ...       ...       ...        ...        ...  ...
# 7747         -1.831134 -0.307886  0.383363  -1.502656  -1.152361  ...
# 7748         -1.843546 -0.063701 -0.363041  -1.466503  -1.187449  ...
# 7749         -1.904782  0.337939 -1.973052  -1.386744  -1.276108  ...
# 7750         -2.891504 -4.119648 -7.414001  -1.694130  -1.649551  ...
# 7751          3.309654  3.033873  3.452681   1.866462   1.920855  ...
#
#       LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4  lat  \
# 0     -0.584801   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 1     -0.603593   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 2     -0.520112   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 3     -0.565449   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 4     -0.365736   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# ...         ...         ...         ...         ...         ...  ...
# 7747  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7748  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7749  -1.474280   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7750  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7751   1.894287    2.163899    2.336183    2.512023    2.631958  0.0
#
#            lon       DEM     Slope  Solar radiation
# 0    -0.027632  1.834978  1.314153         1.849430
# 1     0.497283  0.055979 -0.385336         1.400702
# 2     0.836548 -0.364575 -0.949164         1.380650
# 3     0.368125  0.084879  1.235263         1.357783
# 4     1.871193 -0.290442 -0.401730         1.366748
# ...        ...       ...       ...              ...
# 7747 -1.257759 -1.578128 -1.280447        -1.754608
# 7748 -1.041466 -1.400633 -1.072947        -1.760631
# 7749 -0.291792 -1.193124 -0.935044        -1.744763
# 7750 -2.020630 -1.985144 -1.477264        -1.887071
# 7751  1.871193  1.834978  1.742163         1.849430
#
# [7752 rows x 21 columns]

# %%
x.skew().sort_values(ascending=False)
# Out:
# LDAPS_PPT4          1.963848
# LDAPS_PPT3          1.747820
# LDAPS_PPT2          1.577808
# LDAPS_PPT1          1.404189
# Slope               0.233968
# LDAPS_CC4           0.126895
# LDAPS_CC3           0.087933
# LDAPS_LH            0.057403
# LDAPS_CC1           0.046757
# LDAPS_CC2           0.045326
# DEM                 0.039456
# LDAPS_WS            0.002408
# lat                 0.000000
# LDAPS_Tmax_lapse   -0.009351
# Present_Tmin       -0.012048
# LDAPS_RHmin        -0.017469
# LDAPS_Tmin_lapse   -0.017827
# Present_Tmax       -0.035006
# LDAPS_RHmax        -0.115143
# Solar radiation    -0.176636
# lon                -0.198429
# dtype: float64

# %%
sk=x.skew()

# %%
sk[np.abs(sk)>0.25].all()
# Out:
# True

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
x
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.408897     -0.797707     0.172680     0.272915         -0.556645
# 1         0.705123     -0.720130    -0.241770     0.185831          0.043756
# 2         0.595692     -0.027674    -0.501459    -0.773454          0.127214
# 3         0.741829      0.014910     0.171612     1.316777         -0.006660
# 4         0.523313     -0.602237     0.031496     0.110968         -0.208627
# ...            ...           ...          ...          ...               ...
# 7747     -2.023162     -2.270927    -2.395892    -1.326845         -1.111724
# 7748     -2.023162     -2.087438    -2.681557    -1.470235         -0.902733
# 7749     -2.049920     -2.180066    -2.803707    -1.474702         -0.600985
# 7750     -2.846187     -3.688005    -3.168120    -2.459357         -3.504186
# 7751      2.981037      3.233078     2.489550     2.143982          3.376037
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            -0.312411  0.093387  0.310382  -0.412176  -0.506509  ...
# 1             0.144368 -0.625565 -0.211695  -0.451258  -0.283702  ...
# 2             0.394571 -0.314874 -1.375126  -0.527382  -0.258127  ...
# 3            -0.174463 -0.656732  0.204179  -0.494077  -0.401828  ...
# 4            -0.103881 -0.593836  1.300503  -0.814752  -0.291713  ...
# ...                ...       ...       ...        ...        ...  ...
# 7747         -1.831134 -0.307886  0.383363  -1.502656  -1.152361  ...
# 7748         -1.843546 -0.063701 -0.363041  -1.466503  -1.187449  ...
# 7749         -1.904782  0.337939 -1.973052  -1.386744  -1.276108  ...
# 7750         -2.891504 -4.119648 -7.414001  -1.694130  -1.649551  ...
# 7751          3.309654  3.033873  3.452681   1.866462   1.920855  ...
#
#       LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4  lat  \
# 0     -0.584801   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 1     -0.603593   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 2     -0.520112   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 3     -0.565449   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 4     -0.365736   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# ...         ...         ...         ...         ...         ...  ...
# 7747  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7748  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7749  -1.474280   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7750  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389  0.0
# 7751   1.894287    2.163899    2.336183    2.512023    2.631958  0.0
#
#            lon       DEM     Slope  Solar radiation
# 0    -0.027632  1.834978  1.314153         1.849430
# 1     0.497283  0.055979 -0.385336         1.400702
# 2     0.836548 -0.364575 -0.949164         1.380650
# 3     0.368125  0.084879  1.235263         1.357783
# 4     1.871193 -0.290442 -0.401730         1.366748
# ...        ...       ...       ...              ...
# 7747 -1.257759 -1.578128 -1.280447        -1.754608
# 7748 -1.041466 -1.400633 -1.072947        -1.760631
# 7749 -0.291792 -1.193124 -0.935044        -1.744763
# 7750 -2.020630 -1.985144 -1.477264        -1.887071
# 7751  1.871193  1.834978  1.742163         1.849430
#
# [7752 rows x 21 columns]

# %%
y
# Out:
# 0       21.2
# 1       22.5
# 2       23.9
# 3       24.3
# 4       22.5
#         ...
# 7747    18.1
# 7748    18.8
# 7749    17.4
# 7750    11.3
# 7751    29.8
# Name: Next_Tmin, Length: 7752, dtype: float64

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score

# %%
for i in range (0,2000) :
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    print(f"at random state {i},the training accuracy is :{r2_score(y_train,pred_train)}")
    print(f"at random state {i},the testing accuracy is :{r2_score(y_test,pred_test)}") 
    print("\n")
# Out:
# at random state 0,the training accuracy is :0.8224232365315772
# at random state 0,the testing accuracy is :0.8227647268687935
#
#
# at random state 1,the training accuracy is :0.8211691985546279
# at random state 1,the testing accuracy is :0.8279396428594568
#
#
# at random state 2,the training accuracy is :0.8219908064733977
# at random state 2,the testing accuracy is :0.8241304035956214
#
#
# at random state 3,the training accuracy is :0.8234865857139958
# at random state 3,the testing accuracy is :0.8181535583753503
#
#
# at random state 4,the training accuracy is :0.8192534573273496
# at random state 4,the testing accuracy is :0.8353011232759877
#
#
# at random state 5,the training accuracy is :0.8222591581881427
# at random state 5,the testing accuracy is :0.822768104866799
#
#
# at random state 6,the training accuracy is :0.821134593432221
# at random state 6,the testing accuracy is :0.8275533593043289
#
#
# at random state 7,the training accuracy is :0.8197681240952986
# at random state 7,the testing accuracy is :0.8332828257238818
#
#
# at random state 8,the training accuracy is :0.8246343486319716
# at random state 8,the testing accuracy is :0.8135878799194556
#
#
# at random state 9,the training accuracy is :0.8205919745429466
# at random state 9,the testing accuracy is :0.8300098615212201
#
#
# at random state 10,the training accuracy is :0.819480116563043
# at random state 10,the testing accuracy is :0.8337416334795148
#
#
# at random state 11,the training accuracy is :0.8234404838379468
# at random state 11,the testing accuracy is :0.8184031532485281
#
#
# at random state 12,the training accuracy is :0.8198931696755964
# at random state 12,the testing accuracy is :0.8322776416164297
#
#
# at random state 13,the training accuracy is :0.826145168712299
# at random state 13,the testing accuracy is :0.8066775110390481
#
#
# at random state 14,the training accuracy is :0.825422451844023
# at random state 14,the testing accuracy is :0.8109800147051374
#
#
# at random state 15,the training accuracy is :0.8261394374771905
# at random state 15,the testing accuracy is :0.8081912387392001
#
#
# at random state 16,the training accuracy is :0.8214491987577528
# at random state 16,the testing accuracy is :0.8259952016976607
#
#
# at random state 17,the training accuracy is :0.8217537992193504
# at random state 17,the testing accuracy is :0.8242030648786264
#
#
# at random state 18,the training accuracy is :0.822541857442933
# at random state 18,the testing accuracy is :0.8216370590778579
#
#
# at random state 19,the training accuracy is :0.8227906015876383
# at random state 19,the testing accuracy is :0.821376876012215
#
#
# at random state 20,the training accuracy is :0.8187441066517198
# at random state 20,the testing accuracy is :0.8377178071018246
#
#
# at random state 21,the training accuracy is :0.8205704451653039
# at random state 21,the testing accuracy is :0.8300375048603323
#
#
# at random state 22,the training accuracy is :0.8228264542787775
# at random state 22,the testing accuracy is :0.8205206785405799
#
#
# at random state 23,the training accuracy is :0.8239848120877263
# at random state 23,the testing accuracy is :0.8158645751929696
#
#
# at random state 24,the training accuracy is :0.8221722223903785
# at random state 24,the testing accuracy is :0.8237154867804102
#
#
# at random state 25,the training accuracy is :0.8254404280835148
# at random state 25,the testing accuracy is :0.8113666723320503
#
#
# at random state 26,the training accuracy is :0.8238764883104875
# at random state 26,the testing accuracy is :0.8172324452564089
#
#
# at random state 27,the training accuracy is :0.824777258312223
# at random state 27,the testing accuracy is :0.8123150091190267
#
#
# at random state 28,the training accuracy is :0.8242684596132016
# at random state 28,the testing accuracy is :0.8151282014234652
#
#
# at random state 29,the training accuracy is :0.8209232363745151
# at random state 29,the testing accuracy is :0.8286687246157629
#
#
# at random state 30,the training accuracy is :0.8217437527901152
# at random state 30,the testing accuracy is :0.8255905914780497
#
#
# at random state 31,the training accuracy is :0.8249051367574036
# at random state 31,the testing accuracy is :0.8118640654564533
#
#
# at random state 32,the training accuracy is :0.826081375015332
# at random state 32,the testing accuracy is :0.80751293567343
#
#
# at random state 33,the training accuracy is :0.8241325533619732
# at random state 33,the testing accuracy is :0.8158662633923627
#
#
# at random state 34,the training accuracy is :0.8235153037967319
# at random state 34,the testing accuracy is :0.8180445099462765
#
#
# at random state 35,the training accuracy is :0.8217269854649607
# at random state 35,the testing accuracy is :0.8252341069352658
#
#
# at random state 36,the training accuracy is :0.8198848148621445
# at random state 36,the testing accuracy is :0.8322178489370436
#
#
# at random state 37,the training accuracy is :0.8228714469156982
# at random state 37,the testing accuracy is :0.8209652162954975
#
#
# at random state 38,the training accuracy is :0.8242524857593445
# at random state 38,the testing accuracy is :0.8150085233948877
#
#
# at random state 39,the training accuracy is :0.8220249708839613
# at random state 39,the testing accuracy is :0.8241916274103578
#
#
# at random state 40,the training accuracy is :0.8222755839306407
# at random state 40,the testing accuracy is :0.823229882589941
#
#
# at random state 41,the training accuracy is :0.823335918322837
# at random state 41,the testing accuracy is :0.8191618944130024
#
#
# at random state 42,the training accuracy is :0.8178818984679748
# at random state 42,the testing accuracy is :0.8402220241510374
#
#
# at random state 43,the training accuracy is :0.8191108182707317
# at random state 43,the testing accuracy is :0.8355547817433261
#
#
# at random state 44,the training accuracy is :0.8216918390097097
# at random state 44,the testing accuracy is :0.82445075981092
#
#
# at random state 45,the training accuracy is :0.8234210205233692
# at random state 45,the testing accuracy is :0.8181693276241524
#
#
# at random state 46,the training accuracy is :0.824281327652544
# at random state 46,the testing accuracy is :0.8158487690729994
#
#
# at random state 47,the training accuracy is :0.8216788992742136
# at random state 47,the testing accuracy is :0.8259257194718218
#
#
# at random state 48,the training accuracy is :0.8245135573027884
# at random state 48,the testing accuracy is :0.8143989643230568
#
#
# at random state 49,the training accuracy is :0.8235256915518403
# at random state 49,the testing accuracy is :0.8176419858810982
#
#
# at random state 50,the training accuracy is :0.8257378500809354
# at random state 50,the testing accuracy is :0.8083288390846781
#
#
# at random state 51,the training accuracy is :0.8217460184881143
# at random state 51,the testing accuracy is :0.8254244740077515
#
#
# at random state 52,the training accuracy is :0.821113829378719
# at random state 52,the testing accuracy is :0.8278881296795084
#
#
# at random state 53,the training accuracy is :0.8236000157863073
# at random state 53,the testing accuracy is :0.817807060144916
#
#
# at random state 54,the training accuracy is :0.8196999796424302
# at random state 54,the testing accuracy is :0.832968810184266
#
#
# at random state 55,the training accuracy is :0.8210658701509699
# at random state 55,the testing accuracy is :0.8282216166730256
#
#
# at random state 56,the training accuracy is :0.8183759744758718
# at random state 56,the testing accuracy is :0.8373293096885333
#
#
# at random state 57,the training accuracy is :0.8256726603471657
# at random state 57,the testing accuracy is :0.8095176449483052
#
#
# at random state 58,the training accuracy is :0.8230686826510367
# at random state 58,the testing accuracy is :0.8192592745933307
#
#
# at random state 59,the training accuracy is :0.8213564234924554
# at random state 59,the testing accuracy is :0.826754728651672
#
#
# at random state 60,the training accuracy is :0.8198112200844765
# at random state 60,the testing accuracy is :0.8330377739711705
#
#
# at random state 61,the training accuracy is :0.8225589914287663
# at random state 61,the testing accuracy is :0.8220298803742626
#
#
# at random state 62,the training accuracy is :0.8218174784657943
# at random state 62,the testing accuracy is :0.8248676920480718
#
#
# at random state 63,the training accuracy is :0.8247142306137054
# at random state 63,the testing accuracy is :0.8123196927834497
#
#
# at random state 64,the training accuracy is :0.8244207983612506
# at random state 64,the testing accuracy is :0.8138269137028077
#
#
# at random state 65,the training accuracy is :0.8221827226984412
# at random state 65,the testing accuracy is :0.8235705410619318
#
#
# at random state 66,the training accuracy is :0.822711661159744
# at random state 66,the testing accuracy is :0.8212054750392843
#
#
# at random state 67,the training accuracy is :0.8256442727113488
# at random state 67,the testing accuracy is :0.8090743979513055
#
#
# at random state 68,the training accuracy is :0.8219092199560774
# at random state 68,the testing accuracy is :0.8248626137825155
#
#
# at random state 69,the training accuracy is :0.8192916667521266
# at random state 69,the testing accuracy is :0.8347786450392799
#
#
# at random state 70,the training accuracy is :0.8223967203224098
# at random state 70,the testing accuracy is :0.8226301026315492
#
#
# at random state 71,the training accuracy is :0.8211230297740131
# at random state 71,the testing accuracy is :0.8279508235499499
#
#
# at random state 72,the training accuracy is :0.8234621668375486
# at random state 72,the testing accuracy is :0.8186830578444362
#
#
# at random state 73,the training accuracy is :0.8246549533014332
# at random state 73,the testing accuracy is :0.8135013381193532
#
#
# at random state 74,the training accuracy is :0.8227173943336458
# at random state 74,the testing accuracy is :0.8215302583041912
#
#
# at random state 75,the training accuracy is :0.8210064170435369
# at random state 75,the testing accuracy is :0.8277733827543118
#
#
# at random state 76,the training accuracy is :0.8240132344155076
# at random state 76,the testing accuracy is :0.8161933509460133
#
#
# at random state 77,the training accuracy is :0.8242055834106677
# at random state 77,the testing accuracy is :0.8158085664383063
#
#
# at random state 78,the training accuracy is :0.8223601992380491
# at random state 78,the testing accuracy is :0.8228795259441916
#
#
# at random state 79,the training accuracy is :0.8234174386770523
# at random state 79,the testing accuracy is :0.8186956194667648
#
#
# at random state 80,the training accuracy is :0.825191432150956
# at random state 80,the testing accuracy is :0.811213190250057
#
#
# at random state 81,the training accuracy is :0.8201081408258706
# at random state 81,the testing accuracy is :0.8328441627225309
#
#
# at random state 82,the training accuracy is :0.8231077585296722
# at random state 82,the testing accuracy is :0.8192585388852933
#
#
# at random state 83,the training accuracy is :0.822229585142746
# at random state 83,the testing accuracy is :0.8233197071983189
#
#
# at random state 84,the training accuracy is :0.8229364738441003
# at random state 84,the testing accuracy is :0.8201915556808237
#
#
# at random state 85,the training accuracy is :0.8225925240905538
# at random state 85,the testing accuracy is :0.8222234995962671
#
#
# at random state 86,the training accuracy is :0.8235767897628801
# at random state 86,the testing accuracy is :0.8184217271219789
#
#
# at random state 87,the training accuracy is :0.825127033714263
# at random state 87,the testing accuracy is :0.811113973928201
#
#
# at random state 88,the training accuracy is :0.8208426965626708
# at random state 88,the testing accuracy is :0.8289392985024443
#
#
# at random state 89,the training accuracy is :0.8204000996421434
# at random state 89,the testing accuracy is :0.8305875929205819
#
#
# at random state 90,the training accuracy is :0.8217330647045953
# at random state 90,the testing accuracy is :0.8253779864343744
#
#
# at random state 91,the training accuracy is :0.823439176421383
# at random state 91,the testing accuracy is :0.8184170064515981
#
#
# at random state 92,the training accuracy is :0.8236948635208072
# at random state 92,the testing accuracy is :0.8180169017882248
#
#
# at random state 93,the training accuracy is :0.8199689363231941
# at random state 93,the testing accuracy is :0.8315257265110888
#
#
# at random state 94,the training accuracy is :0.8226333305613367
# at random state 94,the testing accuracy is :0.8220129593584806
#
#
# at random state 95,the training accuracy is :0.8226928350242886
# at random state 95,the testing accuracy is :0.8214938931803188
#
#
# at random state 96,the training accuracy is :0.8232419094071455
# at random state 96,the testing accuracy is :0.8187481068478641
#
#
# at random state 97,the training accuracy is :0.8225312992694286
# at random state 97,the testing accuracy is :0.82214646142889
#
#
# at random state 98,the training accuracy is :0.8206741099266808
# at random state 98,the testing accuracy is :0.8290384983083099
#
#
# at random state 99,the training accuracy is :0.820678122249872
# at random state 99,the testing accuracy is :0.8294647241397182
#
#
# at random state 100,the training accuracy is :0.822227106356994
# at random state 100,the testing accuracy is :0.8233237061416974
#
#
# at random state 101,the training accuracy is :0.8224983898496611
# at random state 101,the testing accuracy is :0.8222955231097554
#
#
# at random state 102,the training accuracy is :0.8219162340644768
# at random state 102,the testing accuracy is :0.8242854100867533
#
#
# at random state 103,the training accuracy is :0.8211144809627454
# at random state 103,the testing accuracy is :0.8276843394256768
#
#
# at random state 104,the training accuracy is :0.8231531344842205
# at random state 104,the testing accuracy is :0.8196967926830787
#
#
# at random state 105,the training accuracy is :0.8216136729447054
# at random state 105,the testing accuracy is :0.8255531292894717
#
#
# at random state 106,the training accuracy is :0.8233263716209229
# at random state 106,the testing accuracy is :0.8193832484614341
#
#
# at random state 107,the training accuracy is :0.821920473514723
# at random state 107,the testing accuracy is :0.8241432668246444
#
#
# at random state 108,the training accuracy is :0.8204551717511387
# at random state 108,the testing accuracy is :0.8303576976456775
#
#
# at random state 109,the training accuracy is :0.8210445734268613
# at random state 109,the testing accuracy is :0.827627470376798
#
#
# at random state 110,the training accuracy is :0.8205265855095765
# at random state 110,the testing accuracy is :0.829946471672661
#
#
# at random state 111,the training accuracy is :0.8225228798541901
# at random state 111,the testing accuracy is :0.8223161052550745
#
#
# at random state 112,the training accuracy is :0.8214638471497905
# at random state 112,the testing accuracy is :0.8266946357893097
#
#
# at random state 113,the training accuracy is :0.8231829973674101
# at random state 113,the testing accuracy is :0.8195273606570371
#
#
# at random state 114,the training accuracy is :0.8237877339776162
# at random state 114,the testing accuracy is :0.8169963284447804
#
#
# at random state 115,the training accuracy is :0.8205796090410256
# at random state 115,the testing accuracy is :0.8298095591768069
#
#
# at random state 116,the training accuracy is :0.8219062033339998
# at random state 116,the testing accuracy is :0.824639332163678
#
#
# at random state 117,the training accuracy is :0.8243471917731626
# at random state 117,the testing accuracy is :0.8145911770200832
#
#
# at random state 118,the training accuracy is :0.8218895982144503
# at random state 118,the testing accuracy is :0.8244689991166145
#
#
# at random state 119,the training accuracy is :0.8213531145206969
# at random state 119,the testing accuracy is :0.8265615582344941
#
#
# at random state 120,the training accuracy is :0.8247290437442374
# at random state 120,the testing accuracy is :0.8131273651070762
#
#
# at random state 121,the training accuracy is :0.822150120393005
# at random state 121,the testing accuracy is :0.8238048989666241
#
#
# at random state 122,the training accuracy is :0.823095601714557
# at random state 122,the testing accuracy is :0.819872017988662
#
#
# at random state 123,the training accuracy is :0.8229473685436115
# at random state 123,the testing accuracy is :0.8205845150592546
#
#
# at random state 124,the training accuracy is :0.8212229096685816
# at random state 124,the testing accuracy is :0.8273340069801938
#
#
# at random state 125,the training accuracy is :0.8260522639149926
# at random state 125,the testing accuracy is :0.8082051006762305
#
#
# at random state 126,the training accuracy is :0.8232053042483438
# at random state 126,the testing accuracy is :0.8193939044622651
#
#
# at random state 127,the training accuracy is :0.8225371442024274
# at random state 127,the testing accuracy is :0.8220950032663534
#
#
# at random state 128,the training accuracy is :0.8262804671361842
# at random state 128,the testing accuracy is :0.8074607977279376
#
#
# at random state 129,the training accuracy is :0.8225116000876299
# at random state 129,the testing accuracy is :0.8221961870012406
#
#
# at random state 130,the training accuracy is :0.8239582821656342
# at random state 130,the testing accuracy is :0.8161774948169755
#
#
# at random state 131,the training accuracy is :0.8207813224477507
# at random state 131,the testing accuracy is :0.8280879689557115
#
#
# at random state 132,the training accuracy is :0.8211984995933508
# at random state 132,the testing accuracy is :0.8275216455898315
#
#
# at random state 133,the training accuracy is :0.8213682300972267
# at random state 133,the testing accuracy is :0.82665559936313
#
#
# at random state 134,the training accuracy is :0.8222731019003585
# at random state 134,the testing accuracy is :0.8233167299832986
#
#
# at random state 135,the training accuracy is :0.8249816035662958
# at random state 135,the testing accuracy is :0.8117100806807725
#
#
# at random state 136,the training accuracy is :0.8221772058757553
# at random state 136,the testing accuracy is :0.8237709444937882
#
#
# at random state 137,the training accuracy is :0.821469059037129
# at random state 137,the testing accuracy is :0.8262949708349052
#
#
# at random state 138,the training accuracy is :0.8230348112105372
# at random state 138,the testing accuracy is :0.8203149370871319
#
#
# at random state 139,the training accuracy is :0.8218651740449041
# at random state 139,the testing accuracy is :0.8243882576853196
#
#
# at random state 140,the training accuracy is :0.8210167976137906
# at random state 140,the testing accuracy is :0.8284760668387847
#
#
# at random state 141,the training accuracy is :0.8225797569732576
# at random state 141,the testing accuracy is :0.8220528722178945
#
#
# at random state 142,the training accuracy is :0.8249110696811756
# at random state 142,the testing accuracy is :0.8120575838368342
#
#
# at random state 143,the training accuracy is :0.819460608268871
# at random state 143,the testing accuracy is :0.8342965544866165
#
#
# at random state 144,the training accuracy is :0.8273293026072532
# at random state 144,the testing accuracy is :0.8014468068317442
#
#
# at random state 145,the training accuracy is :0.8218018962275385
# at random state 145,the testing accuracy is :0.824741095991628
#
#
# at random state 146,the training accuracy is :0.8256649545547008
# at random state 146,the testing accuracy is :0.807921589617109
#
#
# at random state 147,the training accuracy is :0.8204421910264916
# at random state 147,the testing accuracy is :0.8297867546610433
#
#
# at random state 148,the training accuracy is :0.8254386588271452
# at random state 148,the testing accuracy is :0.8100223228293356
#
#
# at random state 149,the training accuracy is :0.8233029600474466
# at random state 149,the testing accuracy is :0.8190367923190773
#
#
# at random state 150,the training accuracy is :0.8239369189464816
# at random state 150,the testing accuracy is :0.8166546757330075
#
#
# at random state 151,the training accuracy is :0.8249500362104624
# at random state 151,the testing accuracy is :0.8120999283578976
#
#
# at random state 152,the training accuracy is :0.8218892907543844
# at random state 152,the testing accuracy is :0.8249086415664977
#
#
# at random state 153,the training accuracy is :0.8226187785353867
# at random state 153,the testing accuracy is :0.8218204441815821
#
#
# at random state 154,the training accuracy is :0.8215160683093332
# at random state 154,the testing accuracy is :0.8264026170383835
#
#
# at random state 155,the training accuracy is :0.8238761036835381
# at random state 155,the testing accuracy is :0.8166419780877172
#
#
# at random state 156,the training accuracy is :0.821144609155678
# at random state 156,the testing accuracy is :0.8272305213147906
#
#
# at random state 157,the training accuracy is :0.822504482372992
# at random state 157,the testing accuracy is :0.8219391263018528
#
#
# at random state 158,the training accuracy is :0.8248011719294713
# at random state 158,the testing accuracy is :0.813023617549917
#
#
# at random state 159,the training accuracy is :0.825017789082431
# at random state 159,the testing accuracy is :0.8122911404530938
#
#
# at random state 160,the training accuracy is :0.8176971463378206
# at random state 160,the testing accuracy is :0.8401854649059124
#
#
# at random state 161,the training accuracy is :0.8240794190297506
# at random state 161,the testing accuracy is :0.8159258679030568
#
#
# at random state 162,the training accuracy is :0.8224561787272121
# at random state 162,the testing accuracy is :0.8226913256459701
#
#
# at random state 163,the training accuracy is :0.8220947846716946
# at random state 163,the testing accuracy is :0.823787343927935
#
#
# at random state 164,the training accuracy is :0.8221445388345318
# at random state 164,the testing accuracy is :0.8239276946466527
#
#
# at random state 165,the training accuracy is :0.8197537325516195
# at random state 165,the testing accuracy is :0.8328177529025573
#
#
# at random state 166,the training accuracy is :0.8219815739245653
# at random state 166,the testing accuracy is :0.8243435261474572
#
#
# at random state 167,the training accuracy is :0.819627936016565
# at random state 167,the testing accuracy is :0.8333499712230338
#
#
# at random state 168,the training accuracy is :0.8200631932570576
# at random state 168,the testing accuracy is :0.8312289566613674
#
#
# at random state 169,the training accuracy is :0.8259408138461057
# at random state 169,the testing accuracy is :0.8075868214840246
#
#
# at random state 170,the training accuracy is :0.8198917781910072
# at random state 170,the testing accuracy is :0.8325950671671865
#
#
# at random state 171,the training accuracy is :0.8201277529735757
# at random state 171,the testing accuracy is :0.8319555534949945
#
#
# at random state 172,the training accuracy is :0.82089269134815
# at random state 172,the testing accuracy is :0.8287697668690254
#
#
# at random state 173,the training accuracy is :0.8260359463894859
# at random state 173,the testing accuracy is :0.8076375159333207
#
#
# at random state 174,the training accuracy is :0.8224781828810604
# at random state 174,the testing accuracy is :0.8224241280620594
#
#
# at random state 175,the training accuracy is :0.8229806542824464
# at random state 175,the testing accuracy is :0.8204959354404853
#
#
# at random state 176,the training accuracy is :0.8201459275811204
# at random state 176,the testing accuracy is :0.8314186638268524
#
#
# at random state 177,the training accuracy is :0.8216102658930238
# at random state 177,the testing accuracy is :0.8260532490887742
#
#
# at random state 178,the training accuracy is :0.8250430493448392
# at random state 178,the testing accuracy is :0.8113946319174776
#
#
# at random state 179,the training accuracy is :0.8226290704947392
# at random state 179,the testing accuracy is :0.8215718566404183
#
#
# at random state 180,the training accuracy is :0.8236864457219744
# at random state 180,the testing accuracy is :0.8174363105462348
#
#
# at random state 181,the training accuracy is :0.8207688174972742
# at random state 181,the testing accuracy is :0.8294259989505446
#
#
# at random state 182,the training accuracy is :0.8236461221860035
# at random state 182,the testing accuracy is :0.8177152064645524
#
#
# at random state 183,the training accuracy is :0.8201415681943808
# at random state 183,the testing accuracy is :0.8314690286971005
#
#
# at random state 184,the training accuracy is :0.8209453084755245
# at random state 184,the testing accuracy is :0.8278425317962098
#
#
# at random state 185,the training accuracy is :0.8241219096545394
# at random state 185,the testing accuracy is :0.8156434938179029
#
#
# at random state 186,the training accuracy is :0.8244882251344141
# at random state 186,the testing accuracy is :0.8145262037437432
#
#
# at random state 187,the training accuracy is :0.8223621471950215
# at random state 187,the testing accuracy is :0.822920473745532
#
#
# at random state 188,the training accuracy is :0.82377804372673
# at random state 188,the testing accuracy is :0.8168618713725841
#
#
# at random state 189,the training accuracy is :0.8253584372591446
# at random state 189,the testing accuracy is :0.8104832180571144
#
#
# at random state 190,the training accuracy is :0.8217241690732283
# at random state 190,the testing accuracy is :0.8255255319237934
#
#
# at random state 191,the training accuracy is :0.8206334679581023
# at random state 191,the testing accuracy is :0.8292925659650675
#
#
# at random state 192,the training accuracy is :0.8218878169077746
# at random state 192,the testing accuracy is :0.8246801187263617
#
#
# at random state 193,the training accuracy is :0.822635425381731
# at random state 193,the testing accuracy is :0.8218928377641181
#
#
# at random state 194,the training accuracy is :0.8205327688650536
# at random state 194,the testing accuracy is :0.8291155072766176
#
#
# at random state 195,the training accuracy is :0.8243909307049805
# at random state 195,the testing accuracy is :0.8147513670100621
#
#
# at random state 196,the training accuracy is :0.8250550802194256
# at random state 196,the testing accuracy is :0.8116504425596921
#
#
# at random state 197,the training accuracy is :0.8266956001599031
# at random state 197,the testing accuracy is :0.8051341419079184
#
#
# at random state 198,the training accuracy is :0.8197800981507101
# at random state 198,the testing accuracy is :0.8326057221739221
#
#
# at random state 199,the training accuracy is :0.8201697732887718
# at random state 199,the testing accuracy is :0.831923685383477
#
#
# at random state 200,the training accuracy is :0.8230996526737953
# at random state 200,the testing accuracy is :0.8192765787814689
#
#
# at random state 201,the training accuracy is :0.8229716515332708
# at random state 201,the testing accuracy is :0.8196944611229464
#
#
# at random state 202,the training accuracy is :0.8220696596241025
# at random state 202,the testing accuracy is :0.8241251461280238
#
#
# at random state 203,the training accuracy is :0.8247088653611861
# at random state 203,the testing accuracy is :0.8132953837785525
#
#
# at random state 204,the training accuracy is :0.8242276763742983
# at random state 204,the testing accuracy is :0.8156919342426723
#
#
# at random state 205,the training accuracy is :0.8199311261682475
# at random state 205,the testing accuracy is :0.8311704999666413
#
#
# at random state 206,the training accuracy is :0.8237982139445643
# at random state 206,the testing accuracy is :0.8169363089233069
#
#
# at random state 207,the training accuracy is :0.8206721823955475
# at random state 207,the testing accuracy is :0.8297973981835134
#
#
# at random state 208,the training accuracy is :0.8234498568689878
# at random state 208,the testing accuracy is :0.8184879809257565
#
#
# at random state 209,the training accuracy is :0.8215018133107217
# at random state 209,the testing accuracy is :0.8260499788096037
#
#
# at random state 210,the training accuracy is :0.8249820694403827
# at random state 210,the testing accuracy is :0.8121012487531857
#
#
# at random state 211,the training accuracy is :0.8267342828233617
# at random state 211,the testing accuracy is :0.8040980943681919
#
#
# at random state 212,the training accuracy is :0.8240926177640078
# at random state 212,the testing accuracy is :0.815765359199777
#
#
# at random state 213,the training accuracy is :0.8208561287302832
# at random state 213,the testing accuracy is :0.8271437603815827
#
#
# at random state 214,the training accuracy is :0.8205568269017045
# at random state 214,the testing accuracy is :0.8290378370711251
#
#
# at random state 215,the training accuracy is :0.8225503345051646
# at random state 215,the testing accuracy is :0.8220946161786193
#
#
# at random state 216,the training accuracy is :0.8220618836114064
# at random state 216,the testing accuracy is :0.8236961386670266
#
#
# at random state 217,the training accuracy is :0.8244926450588649
# at random state 217,the testing accuracy is :0.8142072319468722
#
#
# at random state 218,the training accuracy is :0.8228766456972867
# at random state 218,the testing accuracy is :0.8209513936581504
#
#
# at random state 219,the training accuracy is :0.8191280114752304
# at random state 219,the testing accuracy is :0.8344638808701655
#
#
# at random state 220,the training accuracy is :0.8232929795509538
# at random state 220,the testing accuracy is :0.8187122106380939
#
#
# at random state 221,the training accuracy is :0.822688830971089
# at random state 221,the testing accuracy is :0.8215314877490538
#
#
# at random state 222,the training accuracy is :0.8204942844419795
# at random state 222,the testing accuracy is :0.8299660963770594
#
#
# at random state 223,the training accuracy is :0.822109678094291
# at random state 223,the testing accuracy is :0.8238575268185329
#
#
# at random state 224,the training accuracy is :0.8218982204020352
# at random state 224,the testing accuracy is :0.8248024465206665
#
#
# at random state 225,the training accuracy is :0.8245577372222329
# at random state 225,the testing accuracy is :0.8126121678861852
#
#
# at random state 226,the training accuracy is :0.823162624490859
# at random state 226,the testing accuracy is :0.8198347286867076
#
#
# at random state 227,the training accuracy is :0.825106013487395
# at random state 227,the testing accuracy is :0.8113762533548892
#
#
# at random state 228,the training accuracy is :0.8258902081278308
# at random state 228,the testing accuracy is :0.8057951062658185
#
#
# at random state 229,the training accuracy is :0.8221387149110055
# at random state 229,the testing accuracy is :0.82390886767402
#
#
# at random state 230,the training accuracy is :0.822979462947688
# at random state 230,the testing accuracy is :0.8202692104658563
#
#
# at random state 231,the training accuracy is :0.8249744589682312
# at random state 231,the testing accuracy is :0.811381578463735
#
#
# at random state 232,the training accuracy is :0.822532507015822
# at random state 232,the testing accuracy is :0.8215321131510249
#
#
# at random state 233,the training accuracy is :0.8244599023137833
# at random state 233,the testing accuracy is :0.814725849210174
#
#
# at random state 234,the training accuracy is :0.8214286939681364
# at random state 234,the testing accuracy is :0.8259440761438203
#
#
# at random state 235,the training accuracy is :0.8241238219581561
# at random state 235,the testing accuracy is :0.8149061925848604
#
#
# at random state 236,the training accuracy is :0.8205580867964235
# at random state 236,the testing accuracy is :0.8300441142408135
#
#
# at random state 237,the training accuracy is :0.8177088673776784
# at random state 237,the testing accuracy is :0.8409051160923279
#
#
# at random state 238,the training accuracy is :0.825755242854721
# at random state 238,the testing accuracy is :0.8090475953656651
#
#
# at random state 239,the training accuracy is :0.8273701271973553
# at random state 239,the testing accuracy is :0.8009612434117226
#
#
# at random state 240,the training accuracy is :0.8210902717187993
# at random state 240,the testing accuracy is :0.827725889877515
#
#
# at random state 241,the training accuracy is :0.8220612347721112
# at random state 241,the testing accuracy is :0.8233762684871677
#
#
# at random state 242,the training accuracy is :0.823019733845779
# at random state 242,the testing accuracy is :0.8198217906930085
#
#
# at random state 243,the training accuracy is :0.8215330763600457
# at random state 243,the testing accuracy is :0.8260018228343614
#
#
# at random state 244,the training accuracy is :0.8227569026635502
# at random state 244,the testing accuracy is :0.8210750364931458
#
#
# at random state 245,the training accuracy is :0.8244473148114122
# at random state 245,the testing accuracy is :0.8140838396534774
#
#
# at random state 246,the training accuracy is :0.8195118745341465
# at random state 246,the testing accuracy is :0.8338269952765127
#
#
# at random state 247,the training accuracy is :0.8214386473361404
# at random state 247,the testing accuracy is :0.8263464845797797
#
#
# at random state 248,the training accuracy is :0.8205117815528118
# at random state 248,the testing accuracy is :0.8297550829939454
#
#
# at random state 249,the training accuracy is :0.8215605584385607
# at random state 249,the testing accuracy is :0.8260909120322426
#
#
# at random state 250,the training accuracy is :0.8212187094225222
# at random state 250,the testing accuracy is :0.8274327246705151
#
#
# at random state 251,the training accuracy is :0.8224950245859708
# at random state 251,the testing accuracy is :0.8219510337632602
#
#
# at random state 252,the training accuracy is :0.8216215322731072
# at random state 252,the testing accuracy is :0.825843914226199
#
#
# at random state 253,the training accuracy is :0.8215266010936808
# at random state 253,the testing accuracy is :0.8263950792341845
#
#
# at random state 254,the training accuracy is :0.8238867611476444
# at random state 254,the testing accuracy is :0.8164237493889736
#
#
# at random state 255,the training accuracy is :0.8269857598300915
# at random state 255,the testing accuracy is :0.803007061516111
#
#
# at random state 256,the training accuracy is :0.8211457986437539
# at random state 256,the testing accuracy is :0.8275947991958323
#
#
# at random state 257,the training accuracy is :0.823143345358827
# at random state 257,the testing accuracy is :0.8196442808814423
#
#
# at random state 258,the training accuracy is :0.8234150147174635
# at random state 258,the testing accuracy is :0.818518836163231
#
#
# at random state 259,the training accuracy is :0.8234131874919194
# at random state 259,the testing accuracy is :0.8183403274509629
#
#
# at random state 260,the training accuracy is :0.8219773970045913
# at random state 260,the testing accuracy is :0.8238868738763033
#
#
# at random state 261,the training accuracy is :0.8213440240054477
# at random state 261,the testing accuracy is :0.8262206274382382
#
#
# at random state 262,the training accuracy is :0.8251094579290292
# at random state 262,the testing accuracy is :0.8111904627893014
#
#
# at random state 263,the training accuracy is :0.8213318074876258
# at random state 263,the testing accuracy is :0.8269817006893142
#
#
# at random state 264,the training accuracy is :0.8224806458987082
# at random state 264,the testing accuracy is :0.821824725377724
#
#
# at random state 265,the training accuracy is :0.8227102128511828
# at random state 265,the testing accuracy is :0.8213101221556927
#
#
# at random state 266,the training accuracy is :0.8184124726229342
# at random state 266,the testing accuracy is :0.8375198007375894
#
#
# at random state 267,the training accuracy is :0.8216461905758097
# at random state 267,the testing accuracy is :0.8255852153739801
#
#
# at random state 268,the training accuracy is :0.821587786950185
# at random state 268,the testing accuracy is :0.8262163773823066
#
#
# at random state 269,the training accuracy is :0.8263697664770098
# at random state 269,the testing accuracy is :0.8050386339302699
#
#
# at random state 270,the training accuracy is :0.8232477770640619
# at random state 270,the testing accuracy is :0.8195781392021024
#
#
# at random state 271,the training accuracy is :0.8234828455313759
# at random state 271,the testing accuracy is :0.8179858368925532
#
#
# at random state 272,the training accuracy is :0.8243380490632538
# at random state 272,the testing accuracy is :0.8147907797142377
#
#
# at random state 273,the training accuracy is :0.8265576003150893
# at random state 273,the testing accuracy is :0.805495380465955
#
#
# at random state 274,the training accuracy is :0.8196590177629594
# at random state 274,the testing accuracy is :0.8334867146972537
#
#
# at random state 275,the training accuracy is :0.8216941698635596
# at random state 275,the testing accuracy is :0.8256614346359505
#
#
# at random state 276,the training accuracy is :0.8222914847384735
# at random state 276,the testing accuracy is :0.8234101242874772
#
#
# at random state 277,the training accuracy is :0.8233788764877426
# at random state 277,the testing accuracy is :0.8189307649867684
#
#
# at random state 278,the training accuracy is :0.8240876891647596
# at random state 278,the testing accuracy is :0.8156199650471989
#
#
# at random state 279,the training accuracy is :0.8220664692311035
# at random state 279,the testing accuracy is :0.8237502199192639
#
#
# at random state 280,the training accuracy is :0.8220741204787223
# at random state 280,the testing accuracy is :0.8239205655436898
#
#
# at random state 281,the training accuracy is :0.8212907860480269
# at random state 281,the testing accuracy is :0.8269888640483842
#
#
# at random state 282,the training accuracy is :0.8212392626341359
# at random state 282,the testing accuracy is :0.8272423918036999
#
#
# at random state 283,the training accuracy is :0.8168696453766089
# at random state 283,the testing accuracy is :0.8420508608617933
#
#
# at random state 284,the training accuracy is :0.8255174429050467
# at random state 284,the testing accuracy is :0.8096091003216358
#
#
# at random state 285,the training accuracy is :0.823145500690499
# at random state 285,the testing accuracy is :0.8195367498896017
#
#
# at random state 286,the training accuracy is :0.8225329232654623
# at random state 286,the testing accuracy is :0.8222193762339319
#
#
# at random state 287,the training accuracy is :0.8216193404774781
# at random state 287,the testing accuracy is :0.8256120016460851
#
#
# at random state 288,the training accuracy is :0.8259884369703113
# at random state 288,the testing accuracy is :0.8080725267105301
#
#
# at random state 289,the training accuracy is :0.8241001468126012
# at random state 289,the testing accuracy is :0.8147322805238563
#
#
# at random state 290,the training accuracy is :0.8271263373686141
# at random state 290,the testing accuracy is :0.8033356722141668
#
#
# at random state 291,the training accuracy is :0.8236422408679238
# at random state 291,the testing accuracy is :0.8180078154407918
#
#
# at random state 292,the training accuracy is :0.8201673036063696
# at random state 292,the testing accuracy is :0.8320805704690858
#
#
# at random state 293,the training accuracy is :0.8211723644480655
# at random state 293,the testing accuracy is :0.8276561008333482
#
#
# at random state 294,the training accuracy is :0.8247133759797007
# at random state 294,the testing accuracy is :0.81297529630305
#
#
# at random state 295,the training accuracy is :0.8223923783702887
# at random state 295,the testing accuracy is :0.8230336993672421
#
#
# at random state 296,the training accuracy is :0.8244142007446895
# at random state 296,the testing accuracy is :0.8146055606889011
#
#
# at random state 297,the training accuracy is :0.8239488813639164
# at random state 297,the testing accuracy is :0.8161359493714958
#
#
# at random state 298,the training accuracy is :0.8213341199567135
# at random state 298,the testing accuracy is :0.8270044750909351
#
#
# at random state 299,the training accuracy is :0.8192207202284582
# at random state 299,the testing accuracy is :0.8345675233017563
#
#
# at random state 300,the training accuracy is :0.8223584274685858
# at random state 300,the testing accuracy is :0.8224376774156619
#
#
# at random state 301,the training accuracy is :0.8199721651272398
# at random state 301,the testing accuracy is :0.8322884714856376
#
#
# at random state 302,the training accuracy is :0.8256634011281403
# at random state 302,the testing accuracy is :0.8091368822804383
#
#
# at random state 303,the training accuracy is :0.8218223350321251
# at random state 303,the testing accuracy is :0.8249014663655574
#
#
# at random state 304,the training accuracy is :0.8207651633175911
# at random state 304,the testing accuracy is :0.8290541755873091
#
#
# at random state 305,the training accuracy is :0.8259387772064598
# at random state 305,the testing accuracy is :0.8077512680658612
#
#
# at random state 306,the training accuracy is :0.8208522636306922
# at random state 306,the testing accuracy is :0.8282617048540077
#
#
# at random state 307,the training accuracy is :0.8232664358413583
# at random state 307,the testing accuracy is :0.8195213069797935
#
#
# at random state 308,the training accuracy is :0.8241934796340953
# at random state 308,the testing accuracy is :0.815326079793223
#
#
# at random state 309,the training accuracy is :0.8224633435291993
# at random state 309,the testing accuracy is :0.8221947850411727
#
#
# at random state 310,the training accuracy is :0.825161892540053
# at random state 310,the testing accuracy is :0.8109364369603976
#
#
# at random state 311,the training accuracy is :0.8255325732202762
# at random state 311,the testing accuracy is :0.8102300091892514
#
#
# at random state 312,the training accuracy is :0.8237607043438673
# at random state 312,the testing accuracy is :0.8171737464365569
#
#
# at random state 313,the training accuracy is :0.8242280385671048
# at random state 313,the testing accuracy is :0.8151450882011919
#
#
# at random state 314,the training accuracy is :0.8256680170593377
# at random state 314,the testing accuracy is :0.8091705849021468
#
#
# at random state 315,the training accuracy is :0.8246311582562789
# at random state 315,the testing accuracy is :0.8139826726172931
#
#
# at random state 316,the training accuracy is :0.8236419914687194
# at random state 316,the testing accuracy is :0.817574278978197
#
#
# at random state 317,the training accuracy is :0.8233038769008926
# at random state 317,the testing accuracy is :0.8190775039521286
#
#
# at random state 318,the training accuracy is :0.8246121663493865
# at random state 318,the testing accuracy is :0.8133020512606053
#
#
# at random state 319,the training accuracy is :0.8238797325749686
# at random state 319,the testing accuracy is :0.8169222376694505
#
#
# at random state 320,the training accuracy is :0.8250194460977762
# at random state 320,the testing accuracy is :0.8118746296339798
#
#
# at random state 321,the training accuracy is :0.819985732127818
# at random state 321,the testing accuracy is :0.8317487501235871
#
#
# at random state 322,the training accuracy is :0.8230560554232907
# at random state 322,the testing accuracy is :0.8203519314348688
#
#
# at random state 323,the training accuracy is :0.8188048631654758
# at random state 323,the testing accuracy is :0.8367006897628334
#
#
# at random state 324,the training accuracy is :0.8196517712403644
# at random state 324,the testing accuracy is :0.8328464109674217
#
#
# at random state 325,the training accuracy is :0.8214926434560959
# at random state 325,the testing accuracy is :0.8265543422824118
#
#
# at random state 326,the training accuracy is :0.8220950270809093
# at random state 326,the testing accuracy is :0.8243222451316342
#
#
# at random state 327,the training accuracy is :0.8220000337399522
# at random state 327,the testing accuracy is :0.8239516556672112
#
#
# at random state 328,the training accuracy is :0.8229702120691664
# at random state 328,the testing accuracy is :0.8207794754902458
#
#
# at random state 329,the training accuracy is :0.8255260711193566
# at random state 329,the testing accuracy is :0.8090103625500009
#
#
# at random state 330,the training accuracy is :0.8227345748564088
# at random state 330,the testing accuracy is :0.821424232194959
#
#
# at random state 331,the training accuracy is :0.8236055079582356
# at random state 331,the testing accuracy is :0.8174084201142134
#
#
# at random state 332,the training accuracy is :0.8194971680513211
# at random state 332,the testing accuracy is :0.8335444632014988
#
#
# at random state 333,the training accuracy is :0.8255249029357411
# at random state 333,the testing accuracy is :0.8097561980419694
#
#
# at random state 334,the training accuracy is :0.8240375067579506
# at random state 334,the testing accuracy is :0.8162361482651304
#
#
# at random state 335,the training accuracy is :0.8237634778463103
# at random state 335,the testing accuracy is :0.8175277226278336
#
#
# at random state 336,the training accuracy is :0.8241457666979821
# at random state 336,the testing accuracy is :0.8151036892788199
#
#
# at random state 337,the training accuracy is :0.8264886895036003
# at random state 337,the testing accuracy is :0.8055128499749395
#
#
# at random state 338,the training accuracy is :0.8241664921909723
# at random state 338,the testing accuracy is :0.8157107945704404
#
#
# at random state 339,the training accuracy is :0.8252817697043072
# at random state 339,the testing accuracy is :0.8116198849609657
#
#
# at random state 340,the training accuracy is :0.8217165008163632
# at random state 340,the testing accuracy is :0.8243237487683375
#
#
# at random state 341,the training accuracy is :0.8258664771781281
# at random state 341,the testing accuracy is :0.8074369345257316
#
#
# at random state 342,the training accuracy is :0.8222494061301175
# at random state 342,the testing accuracy is :0.8232418352640267
#
#
# at random state 343,the training accuracy is :0.8221335227798476
# at random state 343,the testing accuracy is :0.823973472408321
#
#
# at random state 344,the training accuracy is :0.8250001160875685
# at random state 344,the testing accuracy is :0.811670318448779
#
#
# at random state 345,the training accuracy is :0.8229135971261746
# at random state 345,the testing accuracy is :0.8205592843162799
#
#
# at random state 346,the training accuracy is :0.8243006963042935
# at random state 346,the testing accuracy is :0.815361991640547
#
#
# at random state 347,the training accuracy is :0.8245076385668698
# at random state 347,the testing accuracy is :0.8147444150876478
#
#
# at random state 348,the training accuracy is :0.8197313019683338
# at random state 348,the testing accuracy is :0.833217270435556
#
#
# at random state 349,the training accuracy is :0.826018461879847
# at random state 349,the testing accuracy is :0.8074164642452484
#
#
# at random state 350,the training accuracy is :0.8198303869800307
# at random state 350,the testing accuracy is :0.8325649511275512
#
#
# at random state 351,the training accuracy is :0.8207932057419227
# at random state 351,the testing accuracy is :0.8295327302167498
#
#
# at random state 352,the training accuracy is :0.8229824246868948
# at random state 352,the testing accuracy is :0.8205316926114363
#
#
# at random state 353,the training accuracy is :0.8257631569262941
# at random state 353,the testing accuracy is :0.8093951212845893
#
#
# at random state 354,the training accuracy is :0.8218421712349309
# at random state 354,the testing accuracy is :0.8248975822502397
#
#
# at random state 355,the training accuracy is :0.8236804031458309
# at random state 355,the testing accuracy is :0.8173942136600546
#
#
# at random state 356,the training accuracy is :0.8278574170435075
# at random state 356,the testing accuracy is :0.8006759202691477
#
#
# at random state 357,the training accuracy is :0.8247850221875039
# at random state 357,the testing accuracy is :0.8126234958024046
#
#
# at random state 358,the training accuracy is :0.8220800402359902
# at random state 358,the testing accuracy is :0.8237472450643557
#
#
# at random state 359,the training accuracy is :0.8245991100427966
# at random state 359,the testing accuracy is :0.8134287647101806
#
#
# at random state 360,the training accuracy is :0.8222913339351009
# at random state 360,the testing accuracy is :0.8231446141742358
#
#
# at random state 361,the training accuracy is :0.8230138850712432
# at random state 361,the testing accuracy is :0.8196116729991498
#
#
# at random state 362,the training accuracy is :0.824306156329472
# at random state 362,the testing accuracy is :0.8151046548032744
#
#
# at random state 363,the training accuracy is :0.8205990132571085
# at random state 363,the testing accuracy is :0.830074821992778
#
#
# at random state 364,the training accuracy is :0.8231152631750757
# at random state 364,the testing accuracy is :0.819787600025729
#
#
# at random state 365,the training accuracy is :0.8205644632092521
# at random state 365,the testing accuracy is :0.8290766059290449
#
#
# at random state 366,the training accuracy is :0.8239948649769777
# at random state 366,the testing accuracy is :0.8162768903859536
#
#
# at random state 367,the training accuracy is :0.824366182054275
# at random state 367,the testing accuracy is :0.8129418163306827
#
#
# at random state 368,the training accuracy is :0.8218254900142665
# ...
# at random state 1879,the testing accuracy is :0.8134916569730236
#
#
# at random state 1880,the training accuracy is :0.8201444360747963
# at random state 1880,the testing accuracy is :0.8311042253947573
#
#
# at random state 1881,the training accuracy is :0.8246987911658925
# at random state 1881,the testing accuracy is :0.8133839445488478
#
#
# at random state 1882,the training accuracy is :0.8221040157974264
# at random state 1882,the testing accuracy is :0.8235595609689337
#
#
# at random state 1883,the training accuracy is :0.8211432092437048
# at random state 1883,the testing accuracy is :0.8277742233652776
#
#
# at random state 1884,the training accuracy is :0.82334434996781
# at random state 1884,the testing accuracy is :0.8191093430372354
#
#
# at random state 1885,the training accuracy is :0.8226639289134606
# at random state 1885,the testing accuracy is :0.8215047980171634
#
#
# at random state 1886,the training accuracy is :0.8210183323783407
# at random state 1886,the testing accuracy is :0.8281131115515921
#
#
# at random state 1887,the training accuracy is :0.8228235276670384
# at random state 1887,the testing accuracy is :0.8208327164497158
#
#
# at random state 1888,the training accuracy is :0.8236076899908324
# at random state 1888,the testing accuracy is :0.8180725915611893
#
#
# at random state 1889,the training accuracy is :0.8221183762795988
# at random state 1889,the testing accuracy is :0.8239066695170614
#
#
# at random state 1890,the training accuracy is :0.8208474829733264
# at random state 1890,the testing accuracy is :0.8287574500813046
#
#
# at random state 1891,the training accuracy is :0.8202949119887323
# at random state 1891,the testing accuracy is :0.8307855640193864
#
#
# at random state 1892,the training accuracy is :0.8204466721137809
# at random state 1892,the testing accuracy is :0.8303576942979259
#
#
# at random state 1893,the training accuracy is :0.823579012887095
# at random state 1893,the testing accuracy is :0.8180012137346196
#
#
# at random state 1894,the training accuracy is :0.820722665394304
# at random state 1894,the testing accuracy is :0.8300936192355046
#
#
# at random state 1895,the training accuracy is :0.8212052920074716
# at random state 1895,the testing accuracy is :0.827806119135301
#
#
# at random state 1896,the training accuracy is :0.821506742411767
# at random state 1896,the testing accuracy is :0.8262977044340133
#
#
# at random state 1897,the training accuracy is :0.8234945800396374
# at random state 1897,the testing accuracy is :0.8183547419923851
#
#
# at random state 1898,the training accuracy is :0.8238266436816319
# at random state 1898,the testing accuracy is :0.8165644200622822
#
#
# at random state 1899,the training accuracy is :0.8238121304270671
# at random state 1899,the testing accuracy is :0.8168529488027205
#
#
# at random state 1900,the training accuracy is :0.8209696921463904
# at random state 1900,the testing accuracy is :0.8283560278622808
#
#
# at random state 1901,the training accuracy is :0.8209766624413559
# at random state 1901,the testing accuracy is :0.8285569135751822
#
#
# at random state 1902,the training accuracy is :0.82574732784791
# at random state 1902,the testing accuracy is :0.8089146585692836
#
#
# at random state 1903,the training accuracy is :0.8246088983334803
# at random state 1903,the testing accuracy is :0.8133739767283845
#
#
# at random state 1904,the training accuracy is :0.8221284125763078
# at random state 1904,the testing accuracy is :0.8239179379420001
#
#
# at random state 1905,the training accuracy is :0.8244549226700679
# at random state 1905,the testing accuracy is :0.8147078501175804
#
#
# at random state 1906,the training accuracy is :0.822701470445421
# at random state 1906,the testing accuracy is :0.8211250235824429
#
#
# at random state 1907,the training accuracy is :0.8221670155605001
# at random state 1907,the testing accuracy is :0.8237377290714032
#
#
# at random state 1908,the training accuracy is :0.8229243310418981
# at random state 1908,the testing accuracy is :0.8205682742553142
#
#
# at random state 1909,the training accuracy is :0.823664124328455
# at random state 1909,the testing accuracy is :0.8172001757688702
#
#
# at random state 1910,the training accuracy is :0.8250270239862147
# at random state 1910,the testing accuracy is :0.8121556371573769
#
#
# at random state 1911,the training accuracy is :0.8256570419337476
# at random state 1911,the testing accuracy is :0.8093103468022926
#
#
# at random state 1912,the training accuracy is :0.8217809558086074
# at random state 1912,the testing accuracy is :0.8251494715769787
#
#
# at random state 1913,the training accuracy is :0.8221649062251798
# at random state 1913,the testing accuracy is :0.8234564582306598
#
#
# at random state 1914,the training accuracy is :0.821686603592434
# at random state 1914,the testing accuracy is :0.8260925236890782
#
#
# at random state 1915,the training accuracy is :0.8222247135614743
# at random state 1915,the testing accuracy is :0.823392079013451
#
#
# at random state 1916,the training accuracy is :0.8209332252381377
# at random state 1916,the testing accuracy is :0.828014243359708
#
#
# at random state 1917,the training accuracy is :0.8248235425471736
# at random state 1917,the testing accuracy is :0.8124416067651613
#
#
# at random state 1918,the training accuracy is :0.8216109979436064
# at random state 1918,the testing accuracy is :0.8259216194876524
#
#
# at random state 1919,the training accuracy is :0.8227199796046717
# at random state 1919,the testing accuracy is :0.8213723070755068
#
#
# at random state 1920,the training accuracy is :0.8212581864264015
# at random state 1920,the testing accuracy is :0.826713502140157
#
#
# at random state 1921,the training accuracy is :0.8207929209579538
# at random state 1921,the testing accuracy is :0.8288321215923427
#
#
# at random state 1922,the training accuracy is :0.821902331028893
# at random state 1922,the testing accuracy is :0.8249510648022577
#
#
# at random state 1923,the training accuracy is :0.8208090206585581
# at random state 1923,the testing accuracy is :0.8287222909686777
#
#
# at random state 1924,the training accuracy is :0.8240806406714569
# at random state 1924,the testing accuracy is :0.8161961358161003
#
#
# at random state 1925,the training accuracy is :0.8231402851798746
# at random state 1925,the testing accuracy is :0.8196512069530177
#
#
# at random state 1926,the training accuracy is :0.8217574274694347
# at random state 1926,the testing accuracy is :0.8253949539108176
#
#
# at random state 1927,the training accuracy is :0.8236954828151672
# at random state 1927,the testing accuracy is :0.817550467696873
#
#
# at random state 1928,the training accuracy is :0.8250883467599981
# at random state 1928,the testing accuracy is :0.8112895307800614
#
#
# at random state 1929,the training accuracy is :0.8215056831420076
# at random state 1929,the testing accuracy is :0.8264784317580096
#
#
# at random state 1930,the training accuracy is :0.8204338883128033
# at random state 1930,the testing accuracy is :0.8313188147138293
#
#
# at random state 1931,the training accuracy is :0.8252131250944889
# at random state 1931,the testing accuracy is :0.811679093465479
#
#
# at random state 1932,the training accuracy is :0.8239574108152089
# at random state 1932,the testing accuracy is :0.816486985065666
#
#
# at random state 1933,the training accuracy is :0.8193806642155022
# at random state 1933,the testing accuracy is :0.8346977540303758
#
#
# at random state 1934,the training accuracy is :0.8249558055013497
# at random state 1934,the testing accuracy is :0.8119712167343147
#
#
# at random state 1935,the training accuracy is :0.8226481500643096
# at random state 1935,the testing accuracy is :0.821448977550137
#
#
# at random state 1936,the training accuracy is :0.8250472877261927
# at random state 1936,the testing accuracy is :0.8116393009745
#
#
# at random state 1937,the training accuracy is :0.8194645180654531
# at random state 1937,the testing accuracy is :0.8339160569327067
#
#
# at random state 1938,the training accuracy is :0.8213472468805446
# at random state 1938,the testing accuracy is :0.8264680817276346
#
#
# at random state 1939,the training accuracy is :0.8221014348274658
# at random state 1939,the testing accuracy is :0.8237047843747765
#
#
# at random state 1940,the training accuracy is :0.8206706144403411
# at random state 1940,the testing accuracy is :0.8291889924351774
#
#
# at random state 1941,the training accuracy is :0.8267452769118839
# at random state 1941,the testing accuracy is :0.8044161620990187
#
#
# at random state 1942,the training accuracy is :0.8187702529597194
# at random state 1942,the testing accuracy is :0.8365197317408726
#
#
# at random state 1943,the training accuracy is :0.8251514541851637
# at random state 1943,the testing accuracy is :0.8114854246491117
#
#
# at random state 1944,the training accuracy is :0.8299228504073661
# at random state 1944,the testing accuracy is :0.7885384618277828
#
#
# at random state 1945,the training accuracy is :0.8248585084322767
# at random state 1945,the testing accuracy is :0.8123646075816094
#
#
# at random state 1946,the training accuracy is :0.820145261625345
# at random state 1946,the testing accuracy is :0.8318960542301629
#
#
# at random state 1947,the training accuracy is :0.825195625005313
# at random state 1947,the testing accuracy is :0.8118727452090987
#
#
# at random state 1948,the training accuracy is :0.8251857270622709
# at random state 1948,the testing accuracy is :0.8109887843686066
#
#
# at random state 1949,the training accuracy is :0.8217636932150099
# at random state 1949,the testing accuracy is :0.8253943257950137
#
#
# at random state 1950,the training accuracy is :0.8217337004416281
# at random state 1950,the testing accuracy is :0.8251944652280379
#
#
# at random state 1951,the training accuracy is :0.8236727201792492
# at random state 1951,the testing accuracy is :0.817671303044721
#
#
# at random state 1952,the training accuracy is :0.8251284943442466
# at random state 1952,the testing accuracy is :0.8114362725458668
#
#
# at random state 1953,the training accuracy is :0.818457477303027
# at random state 1953,the testing accuracy is :0.8386463343774149
#
#
# at random state 1954,the training accuracy is :0.8212072266984995
# at random state 1954,the testing accuracy is :0.8272234890843171
#
#
# at random state 1955,the training accuracy is :0.8224521816851397
# at random state 1955,the testing accuracy is :0.8224702167114277
#
#
# at random state 1956,the training accuracy is :0.8204357911798132
# at random state 1956,the testing accuracy is :0.830803855878963
#
#
# at random state 1957,the training accuracy is :0.8223256142580088
# at random state 1957,the testing accuracy is :0.8230808503764397
#
#
# at random state 1958,the training accuracy is :0.822040534830518
# at random state 1958,the testing accuracy is :0.8235706322170704
#
#
# at random state 1959,the training accuracy is :0.8195990446973392
# at random state 1959,the testing accuracy is :0.8332889212595571
#
#
# at random state 1960,the training accuracy is :0.8239030266957392
# at random state 1960,the testing accuracy is :0.8168867346680315
#
#
# at random state 1961,the training accuracy is :0.8229227032382812
# at random state 1961,the testing accuracy is :0.8209035320281767
#
#
# at random state 1962,the training accuracy is :0.8250882630897398
# at random state 1962,the testing accuracy is :0.8113555980615776
#
#
# at random state 1963,the training accuracy is :0.8256800399413776
# at random state 1963,the testing accuracy is :0.8101568515676725
#
#
# at random state 1964,the training accuracy is :0.8213714143272566
# at random state 1964,the testing accuracy is :0.8261207339213213
#
#
# at random state 1965,the training accuracy is :0.8245715981153495
# at random state 1965,the testing accuracy is :0.8139046999305848
#
#
# at random state 1966,the training accuracy is :0.8250810851567653
# at random state 1966,the testing accuracy is :0.8112799612704411
#
#
# at random state 1967,the training accuracy is :0.822881666562082
# at random state 1967,the testing accuracy is :0.8204753743863951
#
#
# at random state 1968,the training accuracy is :0.8240567782778634
# at random state 1968,the testing accuracy is :0.8157842437115398
#
#
# at random state 1969,the training accuracy is :0.8212931095903578
# at random state 1969,the testing accuracy is :0.8274763897238058
#
#
# at random state 1970,the training accuracy is :0.823158211937065
# at random state 1970,the testing accuracy is :0.8197714979094176
#
#
# at random state 1971,the training accuracy is :0.8236505489639205
# at random state 1971,the testing accuracy is :0.8176486968726351
#
#
# at random state 1972,the training accuracy is :0.8184733514078603
# at random state 1972,the testing accuracy is :0.8374371973741813
#
#
# at random state 1973,the training accuracy is :0.8256967187254424
# at random state 1973,the testing accuracy is :0.8087597644470941
#
#
# at random state 1974,the training accuracy is :0.8236570568833956
# at random state 1974,the testing accuracy is :0.8174908782479755
#
#
# at random state 1975,the training accuracy is :0.8268427597499222
# at random state 1975,the testing accuracy is :0.8033127276780238
#
#
# at random state 1976,the training accuracy is :0.8256267314881398
# at random state 1976,the testing accuracy is :0.8100069118255282
#
#
# at random state 1977,the training accuracy is :0.8234640244187766
# at random state 1977,the testing accuracy is :0.8185331879634845
#
#
# at random state 1978,the training accuracy is :0.8252582955536801
# at random state 1978,the testing accuracy is :0.8094639430830236
#
#
# at random state 1979,the training accuracy is :0.8205601985631843
# at random state 1979,the testing accuracy is :0.8295386875767304
#
#
# at random state 1980,the training accuracy is :0.8202998897648699
# at random state 1980,the testing accuracy is :0.829476272676775
#
#
# at random state 1981,the training accuracy is :0.8220988670247064
# at random state 1981,the testing accuracy is :0.8232680536870436
#
#
# at random state 1982,the training accuracy is :0.8266045569058029
# at random state 1982,the testing accuracy is :0.8045416368176977
#
#
# at random state 1983,the training accuracy is :0.8239993151277631
# at random state 1983,the testing accuracy is :0.8155689209602763
#
#
# at random state 1984,the training accuracy is :0.8210021035150268
# at random state 1984,the testing accuracy is :0.8282134172178801
#
#
# at random state 1985,the training accuracy is :0.8264927826226338
# at random state 1985,the testing accuracy is :0.8065970656770066
#
#
# at random state 1986,the training accuracy is :0.8234467236894831
# at random state 1986,the testing accuracy is :0.8184870156702551
#
#
# at random state 1987,the training accuracy is :0.8240612086066726
# at random state 1987,the testing accuracy is :0.8162725051638424
#
#
# at random state 1988,the training accuracy is :0.8227123131791605
# at random state 1988,the testing accuracy is :0.8217940600647875
#
#
# at random state 1989,the training accuracy is :0.8233071487612156
# at random state 1989,the testing accuracy is :0.818784600664183
#
#
# at random state 1990,the training accuracy is :0.8190151310103215
# at random state 1990,the testing accuracy is :0.8357705916894393
#
#
# at random state 1991,the training accuracy is :0.823044762491292
# at random state 1991,the testing accuracy is :0.8202295394513068
#
#
# at random state 1992,the training accuracy is :0.8222587777711574
# at random state 1992,the testing accuracy is :0.823282856299032
#
#
# at random state 1993,the training accuracy is :0.8224378609302747
# at random state 1993,the testing accuracy is :0.8223946347735255
#
#
# at random state 1994,the training accuracy is :0.8196316814089993
# at random state 1994,the testing accuracy is :0.8328930089125007
#
#
# at random state 1995,the training accuracy is :0.8207189749224156
# at random state 1995,the testing accuracy is :0.8292423324336655
#
#
# at random state 1996,the training accuracy is :0.8220483034780228
# at random state 1996,the testing accuracy is :0.8241647367643194
#
#
# at random state 1997,the training accuracy is :0.8220442274018498
# at random state 1997,the testing accuracy is :0.8233273296447859
#
#
# at random state 1998,the training accuracy is :0.8243115515068321
# at random state 1998,the testing accuracy is :0.8152534423502615
#
#
# at random state 1999,the training accuracy is :0.8230660082876966
# at random state 1999,the testing accuracy is :0.8197865420020384

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=49)

# %%
x_train.shape
# Out:
# (6201, 21)

# %%
y_train.shape
# Out:
# (6201,)

# %%
x_test.shape
# Out:
# (1551, 21)

# %%
y_test.shape
# Out:
# (1551,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.8176419858810982

# %% [markdown]
# # CROSS VALIDATION

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and accuracy score for testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.7941918309667273 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982
#
#
# At cross fold 3 the cv score is 0.7627487747229211 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982
#
#
# At cross fold 4 the cv score is 0.7763133679120643 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982
#
#
# At cross fold 5 the cv score is 0.7642835198357105 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982
#
#
# At cross fold 6 the cv score is 0.7455411233242405 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982
#
#
# At cross fold 7 the cv score is 0.7547480203355786 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982
#
#
# At cross fold 8 the cv score is 0.7546130696963174 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982
#
#
# At cross fold 9 the cv score is 0.6625919877962342 and accuracy score for training is -0.8174636528014618and accuracy score for testing is 0.8176419858810982

# %% [markdown]
# # Plot the Data

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.title("Linear Regression")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.8176790689363205

# %%
cv_score=cross_val_score(ls,x,y,cv=2)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.7943836089952487

# %% [markdown]
# # Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

# %%
rf=RandomForestRegressor(criterion='mse',max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)


rfs=r2_score(y_test,pred_decision)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=2)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)

# %%
import pickle

# %%
filename='Next_Tmin.pkl'
pickle.dump(rf, open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
loaded_model= pickle.load(open('Next_Tmin.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["predicted","original"])
conclusion

# %% [raw]
# Here we see that the set of parameters or independent variables used to predict both the Next day max temp and Next day min temp are same thus we see that the accuracy of the model is same which shows that it is a very good trained model and is able to predict the temperatures correctly. The accuracy for Next_Tmax is 90.22% and for Next_Tmin is 90.18%.This will help the forecasters to better predict the temperature
